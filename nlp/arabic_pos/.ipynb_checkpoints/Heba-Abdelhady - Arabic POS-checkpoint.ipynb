# %% [markdown]
# **Instruction for POS Tagging Using RNNs with Arabic Dataset**
#
# **Dataset:**
# The dataset provided is named "Assignment 2 - Arabic POS.conllu". It contains labeled data for Arabic text with Part-of-Speech (POS) tags in CoNLL-U format.
#
# **Objective:**
# Your objective is to perform Part-of-Speech (POS) tagging on Arabic text using Recurrent Neural Networks (RNNs). Specifically, you will use the Universal POS (UPOS) tags for tagging. UPOS is a standardized set of POS tags that aims to cover all languages.
#
# **Evaluation metric:**
# Accuracy
#
# **Instructions:**
# 1. **Data Preprocessing:**
#    - Load the provided dataset "Assignment 2 - Arabic POS.conllu". You can use pyconll library
#    - Preprocess the data as necessary, including tokenization
#
# 2. **Model Building:**
#    - Design an RNN-based model architecture suitable for POS tagging. You may consider using recurrent layers such as (LSTM) or (GRU).
#    - Define the input and output layers of the model. The input layer should accept sequences of tokens, and the output layer should produce the predicted UPOS tags for each token.
#
# 3. **Training:**
#
# 4. **Evaluation:**
#
# **Additional Notes:**
# - Make sure to document your code thoroughly and provide clear explanations for each step.
# - Feel free to explore different RNN architectures, hyperparameters, and optimization techniques to improve the model's accuracy.

# %% [markdown]
# ### Import used libraries

# %%
# !pip install pyconll
# Out:
# Requirement already satisfied: pyconll in d:\iti\python\conda\lib\site-packages (3.2.0)

# %%
import pyconll
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Embedding, LSTM, GRU, Bidirectional, Dense
from keras.callbacks import EarlyStopping

# %% [markdown]
# ### Load Dataset

# %%
dataset = pyconll.load_from_file("Assignment 2 - Arabic POS.conllu")

# %% [markdown]
# ### Data splitting

# %%
# Extract tokens and POS tags
sentences = []
upos_tags = []

for sentence in dataset:
    tokens = []
    tags = []
    for token in sentence:
        tokens.append(token.form)
        tags.append(token.upos)
    sentences.append(tokens)
    upos_tags.append(tags)

# %%
# Split data into training and testing sets
sentences_train, sentences_test, upos_tags_train, upos_tags_test = train_test_split(
    sentences, upos_tags, test_size=0.2, random_state=42)

# %%
sentences_train
# Out:
# [['كشفت',
#   'الأوراق',
#   'والمستندات',
#   'و',
#   'المستندات',
#   'أن',
#   'المستشفى',
#   'تهرب',
#   'من',
#   'طلبات',
#   'المستشفيات',
#   'الحكومية',
#   'من',
#   'الدم',
#   'باعتبارها',
#   'ب',
#   'اعتبار',
#   'ها',
#   'تأخذ',
#   'الدم',
#   'مجاناً',
#   'وكان',
#   'و',
#   'كان',
#   'يتم',
#   'إبلاغ',
#   'غرفة',
#   'الطوارئ',
#   'بوزارة',
#   'ب',
#   'وزارة',
#   'الصحة',
#   'بكميات',
#   'ب',
#   'كميات',
#   'دم',
#   'أقل',
#   'مما',
#   'من',
#   'ما',
#   'هو',
#   'مدون',
#   'بالأوراق',
#   'ب',
#   'الأوراق',
#   'الرسمية',
#   'لعدم',
#   'ل',
#   'عدم',
#   'الاستعانة',
#   'بكميات',
#   'ب',
#   'كميات',
#   'الدم',
#   'في',
#   'الحوادث',
#   'وحالات',
#   'و',
#   'حالات',
#   'النزيف',
#   'الحاد',
#   '.'],
#  ['ومن',
#   'و',
#   'من',
#   'المتوقع',
#   'ان',
#   'يستقبل',
#   'امير',
#   'قطر',
#   'الاربعاء',
#   'في',
#   'الفندق',
#   'الذي',
#   'يقيم',
#   'فيه',
#   'في',
#   'ه',
#   'كلا',
#   'من',
#   'رئيس',
#   'المجلس',
#   'النيابي',
#   'نبيه',
#   'بري',
#   'ورئيس',
#   'و',
#   'رئيس',
#   'الحكومة',
#   'سليم',
#   'الحص',
#   '.'],
#  ['من', 'هنا', '.', '.'],
#  ['وتعتزم',
#   'و',
#   'تعتزم',
#   'الهند',
#   'من',
#   'جهتها',
#   'جهة',
#   'ها',
#   'شراء',
#   'حاملة',
#   'الطائرات',
#   'الروسية',
#   '"',
#   'اميرال',
#   'غورشكوف',
#   '"',
#   'وستشتري',
#   'و',
#   'س',
#   'تشتري',
#   'طائرات',
#   'ميغ',
#   '-',
#   '29',
#   'الوحيدة',
#   'التي',
#   'تتلاءم',
#   'مع',
#   'حاملة',
#   'الطائرات',
#   'هذه',
#   '.',
#   'وقد',
#   'و',
#   'قد',
#   'يشمل',
#   'العقد',
#   'شراء',
#   '60',
#   'طائرة',
#   '.'],
#  ['السودان',
#   'يصف',
#   'تقرير',
#   'الخارجية',
#   'الامريكية',
#   'بانه',
#   'ب',
#   'أن',
#   'ه',
#   'صدمة',
#   'للسودانيين',
#   'للسودانيين'],
#  ['كشف',
#   'تقرير',
#   'صادر',
#   'عن',
#   'جهاز',
#   'التمثيل',
#   'التجاري',
#   'عن',
#   'انخفاض',
#   'حجم',
#   'التبادل',
#   'التجاري',
#   'بين',
#   'مصر',
#   'والفليبين',
#   'و',
#   'الفليبين',
#   'خلال',
#   'الفترة',
#   'من',
#   'يناير',
#   'إلى',
#   'يونيو',
#   'الماضيين',
#   'إلى',
#   '3',
#   'ملايين',
#   'دولار',
#   'مقابل',
#   '3.86',
#   'مليون',
#   'دولار',
#   'خلال',
#   'نفس',
#   'الفترة',
#   'من',
#   'عام',
#   '2002',
#   '.'],
#  ['الخرطوم', '3', 'مايو'],
#  ['ووجه',
#   'و',
#   'وجه',
#   'رئيس',
#   'المجلس',
#   'الهندي',
#   'الدعوة',
#   'لأعضاء',
#   'ل',
#   'أعضاء',
#   'شعبة',
#   'المجوهرات',
#   'المصرية',
#   'برئاسة',
#   'ب',
#   'رئاسة',
#   'شريف',
#   'السرجاني',
#   'للمشاركة',
#   'ل',
#   'المشاركة',
#   'في',
#   'أعمال',
#   'المعرض',
#   'الدولي',
#   'للمجوهرات',
#   'ل',
#   'المجوهرات',
#   'المقرر',
#   'إقامته',
#   'إقامة',
#   'ه',
#   'بالهند',
#   'ب',
#   'الهند',
#   'خلال',
#   'الفترة',
#   'من',
#   '15',
#   'حتى',
#   '19',
#   'يوليو',
#   'القادم',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'رئيس',
#   'الوزراء',
#   'في',
#   'تصريحات',
#   'مساء',
#   'أول',
#   'من',
#   'امس',
#   'إن',
#   'الحكومة',
#   'تجري',
#   'مراجعة',
#   'يومية',
#   'لاثار',
#   'ل',
#   'آثار',
#   'الحرب',
#   'في',
#   'افغانستان',
#   'على',
#   'الاقتصاد',
#   'وإعداد',
#   'و',
#   'إعداد',
#   'تقارير',
#   'في',
#   'شأنها',
#   'شأن',
#   'ها',
#   'بالتعاون',
#   'ب',
#   'التعاون',
#   'مع',
#   'مؤسسات',
#   'دولية',
#   'من',
#   'بينها',
#   'بين',
#   'ها',
#   'صندوق',
#   'النقد',
#   'والبنك',
#   'و',
#   'البنك',
#   'الدوليين',
#   '،',
#   'ويتم',
#   'و',
#   'يتم',
#   'بناء',
#   'عليها',
#   'علي',
#   'ها',
#   'حصر',
#   'الاثار',
#   'الحالية',
#   'والمتوقعة',
#   'و',
#   'المتوقعة',
#   '،',
#   'قدر',
#   'الامكان',
#   '،',
#   'على',
#   'الاقتصاد',
#   'القومي',
#   'وتحديد',
#   'و',
#   'تحديد',
#   'الخطوات',
#   'اللازمة',
#   'للتعاطي',
#   'ل',
#   'التعاطي',
#   'مع',
#   'الموقف',
#   '.'],
#  ['توقيع',
#   'بروتوكول',
#   'بحريني',
#   '-',
#   'قطري',
#   'للنفط',
#   'ل',
#   'النفط',
#   'والغاز',
#   'والغاز'],
#  ['علمت',
#   '"',
#   'العالم',
#   'اليوم',
#   '"',
#   'أن',
#   'وزارة',
#   'الخارجية',
#   'المصرية',
#   'تلقت',
#   'عرضاً',
#   'من',
#   'المفوضية',
#   'الأوروبية',
#   '،',
#   'تقترح',
#   'فيه',
#   'في',
#   'ه',
#   'على',
#   'الحكومة',
#   'المصرية',
#   'بدء',
#   'مفاوضات',
#   'بينهما',
#   'بين',
#   'هما',
#   'في',
#   'التاسع',
#   'من',
#   'الشهر',
#   'الجاري',
#   'حول',
#   'مشروع',
#   'اتفاق',
#   'مواءمة',
#   'لعملية',
#   'ل',
#   'عملية',
#   'توسع',
#   'الاتحاد',
#   'الأوروبي',
#   'لتقنين',
#   'ل',
#   'تقنين',
#   'العلاقات',
#   'بين',
#   'مصر',
#   'والدول',
#   'و',
#   'الدول',
#   'الأوروبية',
#   'العشر',
#   'التي',
#   'من',
#   'المقرر',
#   'انضمامها',
#   'انضمام',
#   'ها',
#   'إلى',
#   'عضوية',
#   'الاتحاد',
#   'الأوروبي',
#   'في',
#   'أوائل',
#   'مايو',
#   'المقبل',
#   '.'],
#  ['كما',
#   'تعهد',
#   'شرودر',
#   'بمواصلة',
#   'ب',
#   'مواصلة',
#   'توثيق',
#   'العلاقات',
#   'مع',
#   'باريس',
#   '،',
#   'قائلا',
#   'ان',
#   'العلاقات',
#   'مع',
#   'فرنسا',
#   'والولايات',
#   'و',
#   'الولايات',
#   'المتحدة',
#   'ذات',
#   'اهمية',
#   'حيوية',
#   'بالنسبة',
#   'ب',
#   'النسبة',
#   'لالمانيا',
#   'ل',
#   'ألمانيا',
#   '.'],
#  ['واتفق',
#   'و',
#   'اتفق',
#   'الوزراء',
#   'فى',
#   'البيان',
#   'الختامى',
#   'الصادر',
#   'فى',
#   'طرابلس',
#   'مساء',
#   'اليوم',
#   'الاربعاء',
#   'عن',
#   'أعمال',
#   'الدورة',
#   'الأولى',
#   'لمؤتمر',
#   'ل',
#   'مؤتمر',
#   'وزراء',
#   'الصحة',
#   'بالاتحاد',
#   'ب',
#   'الاتحاد',
#   'الأفريقى',
#   'على',
#   'ضرورة',
#   'تنفيذ',
#   'البرامج',
#   'المشتركة',
#   'فى',
#   'المجال',
#   'الصحى',
#   'بالقارة',
#   'ب',
#   'القارة',
#   'وتنسيق',
#   'و',
#   'تنسيق',
#   'برامج',
#   'المعونات',
#   'للدول',
#   'ل',
#   'الدول',
#   'الأفريقية',
#   'من',
#   'المنظمات',
#   'الدولية',
#   'المختصة',
#   'ودعوا',
#   'و',
#   'دعوا',
#   'الى',
#   'انشاء',
#   'وكالة',
#   'أفريقية',
#   'لرقابة',
#   'ل',
#   'رقابة',
#   'نوعية',
#   'العقاقير',
#   'والتعاون',
#   'و',
#   'التعاون',
#   'فى',
#   'هذا',
#   'المجال',
#   '.'],
#  ['وتعد',
#   'و',
#   'تعد',
#   'بورصة',
#   'الماس',
#   'في',
#   'إسطنبول',
#   'بتركيا',
#   'ب',
#   'تركيا',
#   'الأقرب',
#   'إلى',
#   'بورصة',
#   'دبي',
#   'جغرافياً',
#   '،',
#   'فيما',
#   'توجد',
#   '24',
#   'بورصة',
#   'شبيهة',
#   'في',
#   'العالم',
#   '.'],
#  ['وقالت',
#   'و',
#   'قالت',
#   'وزارة',
#   'الخارجية',
#   'الروسية',
#   'فى',
#   'بيان',
#   'لها',
#   'ل',
#   'ها',
#   '"',
#   'اننا',
#   'إن',
#   'نا',
#   'نعتبر',
#   'البيان',
#   'الذى',
#   'اعلنه',
#   'أعلن',
#   'ه',
#   'اتال',
#   'بيهارى',
#   'فاجبايى',
#   'فى',
#   'البرلمان',
#   'الهندى',
#   'خطوة',
#   'هامة',
#   'تجاه',
#   'تحسين',
#   'الوضع',
#   'فى',
#   'جنوب',
#   'اسيا',
#   '.',
#   'ونأمل',
#   'و',
#   'نأمل',
#   'فى',
#   'ان',
#   'تتخذ',
#   'باكستان',
#   'خطوات',
#   'ايجابية',
#   'مناسبة',
#   '.',
#   '"',
#   'اعلن',
#   'فاجبايى',
#   'فى',
#   'مجلس',
#   'النواب',
#   'ان',
#   'الهند',
#   'قررت',
#   'تعيين',
#   'مفوض',
#   'سام',
#   'لدى',
#   'باكستان',
#   '،',
#   'واستعادة',
#   'و',
#   'استعادة',
#   'خطوط',
#   'الطيران',
#   'المدنى',
#   'على',
#   'اساس',
#   'تبادلى',
#   '.'],
#  ['حماية', 'التنوع', 'الحيوى', 'البحرى', 'فى', 'جنوب', 'الصين'],
#  ['يمكن',
#   'استنتاج',
#   'هذه',
#   'الوعود',
#   'مما',
#   'من',
#   'ما',
#   'أعلنه',
#   'أعلن',
#   'ه',
#   'صدام',
#   'حسين',
#   'في',
#   'تسجيلاته',
#   'تسجيلات',
#   'ه',
#   'منذ',
#   'هروبه',
#   'هروب',
#   'ه',
#   '،',
#   'ما',
#   'دام',
#   'لم',
#   'يصدر',
#   'أي',
#   'بيان',
#   'يحدد',
#   'برنامجاً',
#   'سياسيا',
#   'بالانتقام',
#   'ب',
#   'الانتقام',
#   'من',
#   '"',
#   'المتخاذلين',
#   '"',
#   'أي',
#   'من',
#   'لم',
#   'يقفوا',
#   'مع',
#   'صدام',
#   '،',
#   'وهم',
#   'و',
#   'هم',
#   'غالبية',
#   'ساحقة',
#   'في',
#   'الجنوب',
#   'والوسط',
#   'و',
#   'الوسط',
#   'وكل',
#   'و',
#   'كل',
#   'كردستان',
#   '.'],
#  ['بعد',
#   'كلمة',
#   'ترحيبية',
#   'باسم',
#   'ب',
#   'اسم',
#   'المعهد',
#   'القاها',
#   'ألقى',
#   'ها',
#   'طارق',
#   'عسيلي',
#   '،',
#   'تحدث',
#   'تشابمان',
#   'عن',
#   '"',
#   'المسيحية',
#   'الصهيونية',
#   '-',
#   'عقيدة',
#   'الخلاص',
#   'الاخير',
#   '"',
#   'فقال',
#   'ف',
#   'قال',
#   ':',
#   '"',
#   'المسيحية',
#   'الصهيونية',
#   'تطلق',
#   'على',
#   'المسيحيين',
#   'الذين',
#   'يدعمون',
#   'الصهيونية',
#   'ودولة',
#   'و',
#   'دولة',
#   'اسرائيل',
#   'لاسباب',
#   'ل',
#   'أسباب',
#   'متعلقة',
#   'بتفسيرهم',
#   'ب',
#   'تفسير',
#   'هم',
#   'للعهدين',
#   'ل',
#   'العهدين',
#   'القديم',
#   'والجديد',
#   'و',
#   'الجديد',
#   '.',
#   'وهناك',
#   'و',
#   'هناك',
#   'عدة',
#   'اراء',
#   'في',
#   'تحديد',
#   'عددهم',
#   'عدد',
#   'هم',
#   '،',
#   'فهم',
#   'ف',
#   'هم',
#   'على',
#   'احد',
#   'التقديرات',
#   'بين',
#   'عشرين',
#   'واربعين',
#   'و',
#   'أربعين',
#   'مليونا',
#   'في',
#   'الولايات',
#   'المتحدة',
#   '،',
#   'فاذا',
#   'ف',
#   'إذا',
#   'كان',
#   'هذا',
#   'العدد',
#   'صحيحا',
#   'فهو',
#   'ف',
#   'هو',
#   'يشكل',
#   'اكثر',
#   'من',
#   'ثلاثة',
#   'اضعاف',
#   'اليهود',
#   'فيها',
#   'في',
#   'ها',
#   '"',
#   '.'],
#  ['الخرطوم', '3', 'مايو'],
#  ['وأضاف',
#   'و',
#   'أضاف',
#   'المصدر',
#   'ذاته',
#   'ذات',
#   'ه',
#   'الذي',
#   'أصر',
#   'على',
#   'عدم',
#   'الكشف',
#   'عن',
#   'اسمه',
#   'اسم',
#   'ه',
#   '،',
#   'أن',
#   'توقيت',
#   'زيارة',
#   'باول',
#   'الذي',
#   'يأتي',
#   'قبل',
#   'يوم',
#   'واحد',
#   'من',
#   'زيارة',
#   'الرئيس',
#   'الفرنسي',
#   'جاك',
#   'شيراك',
#   'لتونس',
#   'ل',
#   'تونس',
#   'التي',
#   'تبدأ',
#   'يوم',
#   '4',
#   '/',
#   '12',
#   'المقبل',
#   '،',
#   'وكذلك',
#   'و',
#   'كذٰلك',
#   'قبل',
#   'ثلاثة',
#   'أيام',
#   'من',
#   'انعقاد',
#   'قمة',
#   'دول',
#   'غرب',
#   'المتوسط',
#   '(',
#   '5',
#   'زائد',
#   '5',
#   ')',
#   'في',
#   'تونس',
#   '،',
#   'يؤكد',
#   'أن',
#   'توقيت',
#   'زيارة',
#   'باول',
#   'إلى',
#   'تونس',
#   'يوم',
#   '3',
#   '/',
#   '12',
#   'المقبل',
#   'لم',
#   'يكن',
#   'من',
#   'قبيل',
#   'الصدفة',
#   'وأن',
#   'و',
#   'أن',
#   'الولايات',
#   'المتحدة',
#   'لا',
#   'تنظر',
#   'بعين',
#   'ب',
#   'عين',
#   'الرضا',
#   'إلى',
#   'تطور',
#   'وتنامي',
#   'و',
#   'تنامي',
#   'العلاقات',
#   'بين',
#   'دول',
#   'غرب',
#   'أوروبا',
#   'والدول',
#   'و',
#   'الدول',
#   'المغاربية',
#   '.'],
#  ['ونقلت',
#   'و',
#   'نقلت',
#   'وكالة',
#   'الانباء',
#   'السودانية',
#   'عن',
#   'مصدر',
#   'امني',
#   'في',
#   'الفشير',
#   'اتهامه',
#   'اتهام',
#   'ه',
#   'عناصر',
#   'من',
#   'المؤتمر',
#   'الوطني',
#   'بتحريض',
#   'ب',
#   'تحريض',
#   'الطلاب',
#   'على',
#   'النزول',
#   'الى',
#   'الشوارع',
#   'واشعال',
#   'و',
#   'إشعال',
#   'النار',
#   'في',
#   'عدد',
#   'من',
#   'المباني',
#   'الحكومية',
#   '.'],
#  ['واشنطن',
#   '15',
#   '-',
#   '9',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'دعا',
#   'الرئيس',
#   'الاميركي',
#   'بيل',
#   'كلينتون',
#   'اليوم',
#   'الجمعة',
#   'الى',
#   'القليل',
#   'من',
#   'الصبر',
#   'في',
#   'محادثات',
#   'السلام',
#   'حول',
#   'الشرق',
#   'الاوسط',
#   'مشيرا',
#   'الى',
#   'عدم',
#   '"',
#   'تحقيق',
#   'اختراق',
#   'مهم',
#   '"',
#   'في',
#   'الاتصالات',
#   'التي',
#   'تجري',
#   'حاليا',
#   'بين',
#   'مسؤولين',
#   'اميركيين',
#   'وفلسطينيين',
#   'و',
#   'فلسطينيين',
#   'واسرائيليين',
#   'و',
#   'إسرائيليين',
#   'في',
#   'نيويورك',
#   '.'],
#  ['التدهور',
#   'المستمر',
#   'في',
#   'الشرق',
#   'الأوسط',
#   'نتيجة',
#   'سياسة',
#   'اسرائيل',
#   'القصيرة',
#   'النظر',
#   'تجاه',
#   'الشعب',
#   'الفلسطيني',
#   '،',
#   'سيكون',
#   'س',
#   'يكون',
#   'أهم',
#   'المواضيع',
#   'التي',
#   'سيثيرها',
#   'س',
#   'يثير',
#   'ها',
#   'الرئيس',
#   'الفرنسي',
#   'جاك',
#   'شيراك',
#   'مع',
#   'نظيره',
#   'نظير',
#   'ه',
#   'الأميركي',
#   'جورج',
#   'بوش',
#   'في',
#   'واشنطن',
#   'يوم',
#   'الثلثاء',
#   'المقبل',
#   '.'],
#  ['9.6', '%', 'نسبة', 'البطالة', 'بالسعودية', 'بالسعودية'],
#  ['واكد',
#   'و',
#   'أكد',
#   'بن',
#   'عامي',
#   'من',
#   'جهة',
#   'اخرى',
#   'ان',
#   'اسرائيل',
#   'اعلنت',
#   '"',
#   'انها',
#   'إن',
#   'ها',
#   'لا',
#   'يمكن',
#   'ان',
#   'تتخلى',
#   'عن',
#   'ارثها',
#   'إرث',
#   'ها',
#   'في',
#   'جبل',
#   'الهيكل',
#   '"',
#   'في',
#   'القدس',
#   'حيث',
#   'يوجد',
#   'الحرم',
#   'القدسي',
#   '.'],
#  ['وذكر',
#   'و',
#   'ذكر',
#   'رئيس',
#   'اتحاد',
#   'الصناعات',
#   'المصرية',
#   'الدكتور',
#   'عبد',
#   'المنعم',
#   'سعودي',
#   'أن',
#   'الاتحاد',
#   'يعتزم',
#   'طرح',
#   'تأسيس',
#   'مركز',
#   'لتسويق',
#   'ل',
#   'تسويق',
#   'السلع',
#   'والمنتجات',
#   'و',
#   'المنتجات',
#   'الصناعية',
#   'المصرية',
#   'في',
#   'المملكة',
#   'بالتعاون',
#   'ب',
#   'التعاون',
#   'مع',
#   'شركات',
#   'سعودية',
#   'متخصصة',
#   'في',
#   'هذا',
#   'المجال',
#   'وذلك',
#   'و',
#   'ذٰلك',
#   'كآلية',
#   'ك',
#   'آلية',
#   'من',
#   'آليات',
#   'النفاذ',
#   'بالمنتجات',
#   'ب',
#   'المنتجات',
#   'المصرية',
#   'إلى',
#   'السوق',
#   'السعودية',
#   'التي',
#   'تتيح',
#   'فرصاً',
#   'واعدة',
#   'للمنتجات',
#   'ل',
#   'المنتجات',
#   'المصرية',
#   'وأكد',
#   'و',
#   'أكد',
#   'سعودي',
#   'أن',
#   'الإمكانات',
#   'المتوفرة',
#   'في',
#   'مصر',
#   'والمملكة',
#   'و',
#   'المملكة',
#   'تؤهلها',
#   'تؤهل',
#   'ها',
#   'لتعاون',
#   'ل',
#   'تعاون',
#   'اقتصادي',
#   'واستثماري',
#   'و',
#   'استثماري',
#   'كبير',
#   '.'],
#  ['ووصف',
#   'و',
#   'وصف',
#   'شيخ',
#   'الأزهر',
#   'منتقديه',
#   'منتقدي',
#   'ه',
#   'من',
#   'علماء',
#   'الأزهر',
#   'الشريف',
#   'بالجهل',
#   'ب',
#   'الجهل',
#   'وقال',
#   'و',
#   'قال',
#   ':'],
#  ['وقال',
#   'و',
#   'قال',
#   'ان',
#   'هنالك',
#   'اجماعا',
#   'مشتركا',
#   'بين',
#   'الصين',
#   'والسعودية',
#   'و',
#   'السعودية',
#   'فى',
#   'هذا',
#   'الشأن',
#   'وان',
#   'و',
#   'إن',
#   'الصين',
#   'سوف',
#   'تتعاون',
#   'مع',
#   'الاطراف',
#   'المعنية',
#   'بما',
#   'ب',
#   'ما',
#   'فيها',
#   'في',
#   'ها',
#   'السعودية',
#   'وسوف',
#   'و',
#   'سوف',
#   'تضطلع',
#   'بدور',
#   'ب',
#   'دور',
#   'نشط',
#   'فى',
#   'اعادة',
#   'الاعمار',
#   'فى',
#   'عراق',
#   'ما',
#   'بعد',
#   'الحرب',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'التقرير',
#   '،',
#   'الذين',
#   'أعلن',
#   'برعاية',
#   'ب',
#   'رعاية',
#   'عمرو',
#   'موسى',
#   'الأمين',
#   'العام',
#   'لجامعة',
#   'ل',
#   'جامعة',
#   'الدول',
#   'العربية',
#   ':'],
#  ['ويقدر',
#   'و',
#   'يقدر',
#   'خبراء',
#   'إجمالي',
#   'المشتركين',
#   'المتوقعين',
#   'في',
#   'الخدمات',
#   'التأمينية',
#   'التقليدية',
#   'بنحو',
#   'ب',
#   'نحو',
#   'ستة',
#   'ملايين',
#   'شخص',
#   '.'],
#  ['أولت',
#   'إسرائيل',
#   'أهمية',
#   'قصوى',
#   'للزيارة',
#   'ل',
#   'الزيارة',
#   'التي',
#   'يقوم',
#   'بها',
#   'ب',
#   'ها',
#   'وزير',
#   'خارجيتها',
#   'خارجية',
#   'ها',
#   'سلفان',
#   'شالوم',
#   'لأثيوبيا',
#   'ل',
#   'أثيوبيا',
#   'واعتبرتها',
#   'و',
#   'اعتبرت',
#   'ها',
#   'اختراقاً',
#   'للقارة',
#   'ل',
#   'القارة',
#   'السوداء',
#   'التي',
#   'لم',
#   'يزر',
#   'وزير',
#   'خارجية',
#   'إسرائيلي',
#   'أياً',
#   'من',
#   'بلدانها',
#   'بلدان',
#   'ها',
#   'منذ',
#   '12',
#   'عاماً',
#   '.'],
#  ['دبى', '3', 'مايو'],
#  ['يحمّلون',
#   'الطوائف',
#   'وزر',
#   'النفر',
#   'من',
#   'المحسوبين',
#   'عليها',
#   'علي',
#   'ها',
#   '،',
#   'والدين',
#   'و',
#   'الدين',
#   'منهم',
#   'من',
#   'هم',
#   'براء',
#   'وهو',
#   'و',
#   'هو',
#   'يردد',
#   ':',
#   'لا',
#   'تخف',
#   'من',
#   'لقاء',
#   'الاشرار',
#   '،',
#   'انهم',
#   'أن',
#   'هم',
#   'يجفّون',
#   'كالعفن',
#   'ك',
#   'العفن',
#   'تحت',
#   'خيوط',
#   'الشمس',
#   '.'],
#  ['ولذلك',
#   'و',
#   'لذٰلك',
#   'عززت',
#   'تونس',
#   'العهد',
#   'الجديد',
#   'مكانة',
#   'كل',
#   'قطاع',
#   'حيوي',
#   'بما',
#   'ب',
#   'ما',
#   'يقوي',
#   'تجذيره',
#   'تجذير',
#   'ه',
#   'في',
#   'خصوصيات',
#   'هويتنا',
#   'هوية',
#   'نا',
#   'العربية',
#   'الاسلامية',
#   '،',
#   'والمعالم',
#   'و',
#   'المعالم',
#   'الدينية',
#   'هي',
#   'احدى',
#   'اهم',
#   'هذه',
#   'القطاعات',
#   'التي',
#   'ارتقت',
#   'كيفا',
#   'وتنامت',
#   'و',
#   'تنامت',
#   'كمّا',
#   'منذ',
#   'انبلاج',
#   'فجر',
#   'السابع',
#   'من',
#   'نوفمبر',
#   'مقارنة',
#   'بما',
#   'ب',
#   'ما',
#   'كانت',
#   'عليه',
#   'علي',
#   'ه',
#   'طيلة',
#   'اربعة',
#   'عشر',
#   'قرنا',
#   '.'],
#  ['تنص',
#   'المذكرة',
#   'على',
#   'تكوين',
#   'لجنة',
#   'تجتمع',
#   'مرتين',
#   'سنوياً',
#   'لمتابعة',
#   'ل',
#   'متابعة',
#   'أنشطة',
#   'التعاون',
#   'المشترك',
#   '.'],
#  ['عاطف',
#   'عبيد',
#   'بضرورة',
#   'ب',
#   'ضرورة',
#   'إعلان',
#   'موقف',
#   'جماعي',
#   'من',
#   'الدول',
#   'العربية',
#   'للدعوة',
#   'ل',
#   'الدعوة',
#   'الأمريكية',
#   'لتمويل',
#   'ل',
#   'تمويل',
#   'إصدار',
#   'صحف',
#   'في',
#   'عدد',
#   'من',
#   'الدول',
#   'العربية',
#   'أو',
#   'بث',
#   'إذاعات',
#   'بتمويل',
#   'ب',
#   'تمويل',
#   'أمريكي',
#   'تعكس',
#   'محاولات',
#   'أمريكية',
#   'لفرض',
#   'ل',
#   'فرض',
#   'صيغة',
#   'إعلامية',
#   'تخدم',
#   'أهدافاً',
#   'خفية',
#   'لصالح',
#   'ل',
#   'صالح',
#   'إسرائيل',
#   '!'],
#  ['وأوضحت',
#   'و',
#   'أوضحت',
#   'منظمات',
#   'الأعمال',
#   'أن',
#   'مصطلح',
#   'الشركات',
#   'ذات',
#   'الشهرة',
#   'العالمية',
#   'هو',
#   'مصطلح',
#   '"',
#   'مطاط',
#   '"',
#   'ولا',
#   'و',
#   'لا',
#   'يمكن',
#   'تعريفه',
#   'تعريف',
#   'ه',
#   'بدقة',
#   'ب',
#   'دقة',
#   'لتحديد',
#   'ل',
#   'تحديد',
#   'الشركات',
#   'التي',
#   'ستمنح',
#   'س',
#   'تمنح',
#   'حوافز',
#   'إضافية',
#   '.'],
#  ['وعلى',
#   'و',
#   'على',
#   'رغم',
#   'أن',
#   'مصادر',
#   'في',
#   '»',
#   'مركز',
#   'البحوث',
#   'العربية',
#   '«',
#   'أكدت',
#   'أن',
#   '»',
#   'أعمال',
#   'الندوة',
#   'بحثية',
#   'وفكرية',
#   'و',
#   'فكرية',
#   '«',
#   '،',
#   'لكنها',
#   'لٰكن',
#   'ها',
#   'لم',
#   'تستبعد',
#   'أن',
#   '»',
#   'تنعكس',
#   'نتائجها',
#   'نتائج',
#   'ها',
#   'على',
#   'تحركات',
#   'شعبية',
#   'عربية',
#   'في',
#   'سياق',
#   'الاحتجاجات',
#   'الدولية',
#   'لمناهضة',
#   'ل',
#   'مناهضة',
#   'منظمة',
#   'التجارة',
#   'العالمية',
#   '«',
#   '.',
#   'ولفتت',
#   'و',
#   'لفتت',
#   'إلى',
#   'أن',
#   '»',
#   'مشاركين',
#   'في',
#   'الندوة',
#   'سينقلون',
#   'س',
#   'ينقلون',
#   'الى',
#   'اجتماع',
#   'الدوحة',
#   'بياناً',
#   'يتضمن',
#   'موقف',
#   'المنظمات',
#   'غير',
#   'الحكومية',
#   'العربية',
#   '.',
#   'ويتوقع',
#   'و',
#   'يتوقع',
#   'تأسيس',
#   'هيئة',
#   'دائمة',
#   'من',
#   'المشاركين',
#   'لمناهضة',
#   'ل',
#   'مناهضة',
#   'مخططات',
#   'القوى',
#   'الدولية',
#   'ومواجهة',
#   'و',
#   'مواجهة',
#   'محاولات',
#   'السيطرة',
#   'على',
#   'الجنوب',
#   '«',
#   '.'],
#  ['وزراء',
#   'خارجية',
#   'الاتحاد',
#   'الاوربى',
#   'يبحثون',
#   'عودة',
#   'البعثات',
#   'الدبلوماسية',
#   'الى',
#   'العراق',
#   'اثينا',
#   '2',
#   'مايو',
#   '/',
#   'شينخوا',
#   '/',
#   'يبحث',
#   'الاتحاد',
#   'الاوربى',
#   'مسألة',
#   'عودة',
#   'البعثات',
#   'الدبلوماسية',
#   'الى',
#   'بغداد',
#   'كأحدى',
#   'ك',
#   'إحدى',
#   'الخطوات',
#   'الاولى',
#   'التى',
#   'يبحثها',
#   'يبحث',
#   'ها',
#   'الاتحاد',
#   'فى',
#   'اعقاب',
#   'الحرب',
#   'العراقية',
#   '.'],
#  ['وحضر',
#   'و',
#   'حضر',
#   'مولير',
#   'إلى',
#   'رفح',
#   'قبل',
#   'عدة',
#   'أيام',
#   'لإنتاج',
#   'ل',
#   'إنتاج',
#   'وتصوير',
#   'و',
#   'تصوير',
#   'فيلم',
#   'وثائقي',
#   'عن',
#   '"',
#   'عمليات',
#   'الهدم',
#   '"',
#   'التي',
#   'ينفذها',
#   'ينفذ',
#   'ها',
#   'الجيش',
#   'الإسرائيلي',
#   'في',
#   'المنطقة',
#   'التي',
#   'عادة',
#   'ما',
#   'تشهد',
#   'اشتباكات',
#   'عنيفة',
#   'بين',
#   'الفلسطينيين',
#   'والإسرائيليين',
#   'و',
#   'الإسرائيليين',
#   '.'],
#  ['ورأت',
#   'و',
#   'رأت',
#   'مطر',
#   'في',
#   'اختيار',
#   'الاتحاد',
#   'ومنظماته',
#   'و',
#   'منظمات',
#   'ه',
#   'المنتشرة',
#   'في',
#   'القارات',
#   'الخمس',
#   'بيروت',
#   'مكاناً',
#   'للمؤتمر',
#   'ل',
#   'المؤتمر',
#   'فرصة',
#   '"',
#   'لترفع',
#   'ل',
#   'ترفع',
#   'نساء',
#   'العالم',
#   'الصوت',
#   'منددة',
#   'بالجرائم',
#   'ب',
#   'الجرائم',
#   'الاسرائيلية',
#   'ولتأكيد',
#   'و',
#   'ل',
#   'تأكيد',
#   'ادانتها',
#   'إدانة',
#   'ها',
#   'واستنكارها',
#   'و',
#   'استنكار',
#   'ها',
#   'للسياسة',
#   'ل',
#   'السياسة',
#   'الصهيونية',
#   'الهادفة',
#   'الى',
#   'ابادة',
#   'الشعب',
#   'الفلسطيني',
#   'وتصفية',
#   'و',
#   'تصفية',
#   'قضيته',
#   'قضية',
#   'ه',
#   'وضرب',
#   'و',
#   'ضرب',
#   'الانتفاضة',
#   '"',
#   '.'],
#  ['وأشار',
#   'و',
#   'أشار',
#   'عدد',
#   'من',
#   'الذين',
#   'شملهم',
#   'شمل',
#   'هم',
#   'الإستطلاع',
#   'الى',
#   'أن',
#   'الحب',
#   'الذي',
#   'يفرحهم',
#   'يفرح',
#   'هم',
#   'ينعكس',
#   'على',
#   'مظهرهم',
#   'مظهر',
#   'هم',
#   'الخارجي',
#   '،',
#   'فيشعرون',
#   'ف',
#   'يشعرون',
#   'أنهم',
#   'أن',
#   'هم',
#   'أكثر',
#   'جمالاً',
#   '.'],
#  ['يبحث',
#   'الوفد',
#   'التجاري',
#   'المصري',
#   'الذي',
#   'من',
#   'المقرر',
#   'أن',
#   'يزور',
#   'المملكة',
#   'العربية',
#   'السعودية',
#   'يوم',
#   '27',
#   '/',
#   '12',
#   'الحالي',
#   'أن',
#   'يزور',
#   'المملكة',
#   'العربية',
#   'السعودية',
#   'يوم',
#   'السبت',
#   'المقبل',
#   'مع',
#   'المسؤولين',
#   'وأعضاء',
#   'و',
#   'أعضاء',
#   'الغرف',
#   'الصناعية',
#   'التجارية',
#   'في',
#   'السعودية',
#   'لتنفيذ',
#   'ل',
#   'تنفيذ',
#   'حزمة',
#   'من',
#   'المشروعات',
#   'المشتركة',
#   'المقترحة',
#   'باستثمارات',
#   'ب',
#   'استثمارات',
#   'تتجاوز',
#   '400',
#   'مليون',
#   'دولار',
#   'تتعلق',
#   'بمجالات',
#   'ب',
#   'مجالات',
#   'السياحة',
#   'والصناعة',
#   'و',
#   'الصناعة',
#   'والزراعة',
#   'و',
#   'الزراعة',
#   'وتكنولوجيا',
#   'و',
#   'تكنولوجيا',
#   'المعلومات',
#   'والقطاع',
#   'و',
#   'القطاع',
#   'الخدمي',
#   '،',
#   'ويعتزم',
#   'و',
#   'يعتزم',
#   'الجانب',
#   'المصري',
#   'الذي',
#   'يضم',
#   'نخبة',
#   'من',
#   'رجال',
#   'الأعمال',
#   'وأعضاء',
#   'و',
#   'أعضاء',
#   'الغرف',
#   'التجارية',
#   'واتحاد',
#   'و',
#   'اتحاد',
#   'الصناعات',
#   'المصرية',
#   'ـ',
#   'حسبما',
#   'ذكرت',
#   'مصادر',
#   'بوزارة',
#   'ب',
#   'وزارة',
#   'التجارة',
#   'الخارجية',
#   'ـ',
#   'طرح',
#   'دراسات',
#   'جدوى',
#   'تتعلق',
#   'بمشروعات',
#   'ب',
#   'مشروعات',
#   'لإنتاج',
#   'ل',
#   'إنتاج',
#   'السيارات',
#   'وتجميع',
#   'و',
#   'تجميع',
#   'الحافلات',
#   'وسيارات',
#   'و',
#   'سيارات',
#   'النقل',
#   'الخفيف',
#   'وتصنيع',
#   'و',
#   'تصنيع',
#   'الأثاث',
#   'والأدوية',
#   'و',
#   'الأدوية',
#   'وتأجير',
#   'و',
#   'تأجير',
#   'خطوط',
#   'إنتاج',
#   'بعض',
#   'المصانع',
#   'المصرية',
#   'خاصة',
#   'في',
#   'قطاع',
#   'الصناعات',
#   'الغذائية',
#   'من',
#   'أجل',
#   'إعداد',
#   'منتجات',
#   'للتصدير',
#   'ل',
#   'التصدير',
#   'للأسواق',
#   'ل',
#   'الأسواق',
#   'العربية',
#   'والأفريقية',
#   'و',
#   'الأفريقية',
#   'والأوروبية',
#   'و',
#   'الأوروبية',
#   'فضلاً',
#   'عن',
#   'بحث',
#   'التعاون',
#   'وتكوين',
#   'و',
#   'تكوين',
#   'كونسورتيوم',
#   'مصري',
#   'ـ',
#   'سعودي',
#   'في',
#   'قطاعات',
#   'النفط',
#   'والمقاولات',
#   'و',
#   'المقاولات',
#   'والصناعات',
#   'و',
#   'الصناعات',
#   'الغذائية',
#   'من',
#   'أجل',
#   'المنافسة',
#   'والحصول',
#   'و',
#   'الحصول',
#   'على',
#   'صفقات',
#   'في',
#   'إطار',
#   'مشروعات',
#   'إعادة',
#   'إعمار',
#   'العراق',
#   '،',
#   'كما',
#   'يبحث',
#   'الوفد',
#   'مشروعات',
#   'أخرى',
#   'في',
#   'مجالات',
#   'السياحة',
#   'العلاجية',
#   'وصناعة',
#   'و',
#   'صناعة',
#   'الكيماويات',
#   'وإنتاج',
#   'و',
#   'إنتاج',
#   'وتخزين',
#   'و',
#   'تخزين',
#   'وتوزيع',
#   'و',
#   'توزيع',
#   'الحبوب',
#   'واستصلاح',
#   'و',
#   'استصلاح',
#   'الأراضي',
#   'لا',
#   'سيما',
#   'في',
#   'منطقة',
#   'جنوب',
#   'الوادي',
#   '.'],
#  ['الدلو'],
#  ['ونقل',
#   'و',
#   'نقل',
#   'عن',
#   'فليكس',
#   'كازاهورا',
#   'المختص',
#   'بشئون',
#   'ب',
#   'شؤون',
#   'اللاجئين',
#   'بمكتب',
#   'ب',
#   'مكتب',
#   'رئيس',
#   'الوزراء',
#   'قوله',
#   'قول',
#   'ه',
#   'إنه',
#   'إن',
#   'ه',
#   'تم',
#   'اتخاذ',
#   'ترتيبات',
#   'لاعادة',
#   'ل',
#   'إعادة',
#   'توطين',
#   'اللاجئين',
#   'الذين',
#   'نزحوا',
#   'بسبب',
#   'ب',
#   'سبب',
#   'غارة',
#   'شنها',
#   'شن',
#   'ها',
#   'المتمردون',
#   'على',
#   'معسكرهم',
#   'معسكر',
#   'هم',
#   'فى',
#   'اشول',
#   '/',
#   'بيل',
#   'بمنطقة',
#   'ب',
#   'منطقة',
#   'بادر',
#   'الشمالية',
#   'فى',
#   'أغسطس',
#   'من',
#   'العام',
#   'الماضى',
#   '.'],
#  ['ومعظم',
#   'و',
#   'معظم',
#   'المرضى',
#   'الموجودين',
#   'فى',
#   'المستشفيات',
#   'حاليا',
#   'يستجيبون',
#   'لنظام',
#   'ل',
#   'نظام',
#   'العلاج',
#   'الجديد',
#   '،',
#   'ويتلقى',
#   'و',
#   'يتلقى',
#   '80',
#   'مريضا',
#   'العلاج',
#   'فى',
#   'وحدة',
#   'العناية',
#   'المركزة',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'قصير',
#   'انه',
#   'إن',
#   'ه',
#   '"',
#   'يمكن',
#   'للعلماء',
#   'ل',
#   'العلماء',
#   'المسلمين',
#   'ان',
#   'يوقعوا',
#   'البيان',
#   'وان',
#   'و',
#   'إن',
#   'اغفال',
#   'موضوع',
#   'الوجود',
#   'السوري',
#   'ليس',
#   'من',
#   'موقع',
#   'عدم',
#   'التطرق',
#   'الى',
#   'قضية',
#   'خلافية',
#   'بل',
#   'من',
#   'اجل',
#   'التوصل',
#   'الى',
#   'نتائج',
#   'ايجابية',
#   '"',
#   '.'],
#  ['افتتاح',
#   'المؤتمر',
#   'الـ',
#   '13',
#   'للاتحاد',
#   'ل',
#   'الاتحاد',
#   'النسائي',
#   'الديموقراطي',
#   'العالمي',
#   'مطـر',
#   ':',
#   'مـن',
#   'عاصمتنـا',
#   'عاصمة',
#   'نا',
#   'ينطلـق',
#   'شعـاع',
#   'النضـال',
#   'جلسات',
#   'عمل'],
#  ['وبدأ',
#   'و',
#   'بدأ',
#   'المبعوث',
#   'الرئاسي',
#   'الاميركي',
#   'جون',
#   'دانفورث',
#   'أمس',
#   'محادثات',
#   'مع',
#   'كبار',
#   'المسؤولين',
#   'السودانيين',
#   'تزامنت',
#   'مع',
#   'بدء',
#   'مفاوضات',
#   'مباشرة',
#   'بين',
#   'وفدين',
#   'رفيعي',
#   'المستوى',
#   'من',
#   'الحكومة',
#   'السودانية',
#   'و',
#   '»',
#   'الحركة',
#   'الشعبية',
#   'لتحرير',
#   'ل',
#   'تحرير',
#   'السودان',
#   '«',
#   'في',
#   'سويسرا',
#   'تحت',
#   'رعاية',
#   'أميركية',
#   '.',
#   '(',
#   'راجع',
#   'ص',
#   '٥',
#   ')',
#   '.',
#   'ورفض',
#   'و',
#   'رفض',
#   'المسؤولون',
#   'السويسريون',
#   'تحديد',
#   'مكان',
#   'الاجتماع',
#   'أو',
#   'كشف',
#   'أسماء',
#   'المشاركين',
#   'فيه',
#   'في',
#   'ه',
#   '.',
#   'وعلمت',
#   'و',
#   'علمت',
#   '»',
#   'الحياة',
#   '«',
#   'أن',
#   'وكيل',
#   'وزارة',
#   'الخارجية',
#   'الدكتور',
#   'مطرف',
#   'صديق',
#   'يرأس',
#   'وفد',
#   'الحكومة',
#   'الذي',
#   'يضم',
#   'يحيي',
#   'حسين',
#   'وصلاح',
#   'و',
#   'صلاح',
#   'عبدالله',
#   'والعميد',
#   'و',
#   'العميد',
#   'محمد',
#   'الشيخ',
#   'التوم',
#   '،',
#   'فيما',
#   'يقود',
#   'وفد',
#   '»',
#   'الحركة',
#   'الشعبية',
#   '«',
#   'عبدالعزيز',
#   'الحلو',
#   'ويشارك',
#   'و',
#   'يشارك',
#   'فيه',
#   'في',
#   'ه',
#   'دينغ',
#   'ألور',
#   'ونيال',
#   'و',
#   'نيال',
#   'دينغ',
#   'وياسر',
#   'و',
#   'ياسر',
#   'عرمان',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'العمير',
#   'ان',
#   'اجمالي',
#   'اشتراكات',
#   'التأمين',
#   'الطبي',
#   'في',
#   'الشركة',
#   'بلغ',
#   '250',
#   'مليون',
#   'ريال',
#   'العام',
#   'الماضي',
#   '،',
#   'لكن',
#   'سوء',
#   'استخدام',
#   'بطاقة',
#   'التأمين',
#   'الطبي',
#   'والتحايل',
#   'و',
#   'التحايل',
#   'من',
#   'بعض',
#   'العملاء',
#   'والمستشفيات',
#   'و',
#   'المستشفيات',
#   'رفع',
#   'معدل',
#   'الخسارة',
#   'في',
#   'محفظة',
#   'التأمين',
#   'الطبي',
#   'الى',
#   '97',
#   'في',
#   'المئة',
#   '،',
#   '»',
#   'ونظراً',
#   'و',
#   'نظرا',
#   'الى',
#   'اننا',
#   'أن',
#   'نا',
#   'نعيد',
#   'تأمين',
#   'جزء',
#   'كبير',
#   'من',
#   'هذا',
#   'النشاط',
#   'لدى',
#   'معيدي',
#   'تأمين',
#   'عالميين',
#   '،',
#   'رفعت',
#   'شركات',
#   'اعادة',
#   'التأمين',
#   'في',
#   'السوق',
#   'العالمية',
#   'اسعار',
#   'التأمين',
#   'الطبي',
#   'على',
#   'الشركة',
#   'ما',
#   'اضطرنا',
#   'اضطر',
#   'نا',
#   'الى',
#   'اعادة',
#   'تقويم',
#   'برامج',
#   'التأمين',
#   'الطبي',
#   'التي',
#   'نصدرها',
#   'نصدر',
#   'ها',
#   'واتخاذ',
#   'و',
#   'اتخاذ',
#   'بعض',
#   'التدابير',
#   'التي',
#   'تحد',
#   'من',
#   'عمليات',
#   'التحايل',
#   '«',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'نيه',
#   'جون',
#   'عضو',
#   'فريق',
#   'خبراء',
#   'مكافحة',
#   'سارس',
#   'التابع',
#   'لوزارة',
#   'ل',
#   'وزارة',
#   'الصحة',
#   'إنه',
#   'إن',
#   'ه',
#   'إلى',
#   'جانب',
#   'بكين',
#   'تضررت',
#   'مناطق',
#   'اخرى',
#   'مثل',
#   'شانشى',
#   'ومنغوليا',
#   'و',
#   'منغوليا',
#   'الداخلية',
#   'وخيبى',
#   'وتيانجين',
#   'فى',
#   'شمالى',
#   'الصين',
#   'بهذا',
#   'ب',
#   'هٰذا',
#   'الوباء',
#   'بشكل',
#   'ب',
#   'شكل',
#   'حاد',
#   '.',
#   'وأضاف',
#   'و',
#   'أضاف',
#   'أنه',
#   'أن',
#   'ه',
#   'تم',
#   'اكتشاف',
#   '66.5',
#   'فى',
#   'المائة',
#   'من',
#   'إجمالى',
#   'حالات',
#   'سارس',
#   'فى',
#   'البر',
#   'الرئيسى',
#   'بالمناطق',
#   'ب',
#   'المناطق',
#   'الخمس',
#   'السابق',
#   'ذكرها',
#   'ذكر',
#   'ها',
#   '.'],
#  ['واقامت',
#   'و',
#   'أقامت',
#   'دورية',
#   'اسرائيلية',
#   'بعدها',
#   'بعد',
#   'ها',
#   'طوقا',
#   'امنيا',
#   'على',
#   'بعد',
#   'بضعة',
#   'امتار',
#   'من',
#   'السواتر',
#   'المعدنية',
#   'المقامة',
#   'على',
#   'الحدود',
#   '.'],
#  ['واضاف',
#   'و',
#   'أضاف',
#   '"',
#   'نريد',
#   'مواصلة',
#   'المفاوضات',
#   'مع',
#   'اسرائيل',
#   'التي',
#   'عليها',
#   'علي',
#   'ها',
#   'ان',
#   'تتعلم',
#   'الالتزام',
#   'بالمواعيد',
#   'ب',
#   'المواعيد',
#   'والاتفاقات',
#   'و',
#   'الاتفاقات',
#   'الموقعة',
#   '"',
#   '،',
#   'مضيفا',
#   'ان',
#   '"',
#   'الاميركيين',
#   'والاوروبيين',
#   'و',
#   'الأوروبيين',
#   'اتفقوا',
#   '(',
#   'في',
#   'ايار',
#   '/',
#   'مايو',
#   '1999',
#   'في',
#   'مصر',
#   ')',
#   'على',
#   'موعد',
#   'الثالث',
#   'عشر',
#   'من',
#   'ايلول',
#   '/',
#   'سبتمبر',
#   '"',
#   'لاعلان',
#   'ل',
#   'إعلان',
#   'الدولة',
#   'الفلسطينية',
#   '.'],
#  ['وقد',
#   'و',
#   'قد',
#   'طلب',
#   'القرار',
#   '1559',
#   'الذي',
#   'قدمته',
#   'قدمت',
#   'ه',
#   'فرنسا',
#   'والولايات',
#   'و',
#   'الولايات',
#   'المتحدة',
#   'ايضا',
#   'من',
#   'سوريا',
#   'وضع',
#   'حد',
#   'لتدخلها',
#   'ل',
#   'تدخل',
#   'ها',
#   'في',
#   'الشؤون',
#   'الداخلية',
#   'اللبنانية',
#   '.'],
#  ['القوات',
#   'الأمريكية',
#   'تكبدت',
#   'خسائر',
#   'منذ',
#   'احتلال',
#   'العراق',
#   'تفوق',
#   'تلك',
#   'التي',
#   'منيت',
#   'بها',
#   'ب',
#   'ها',
#   'في',
#   'فيتنام',
#   'خلال',
#   'السنة',
#   'الأولى',
#   'من',
#   'الحرب',
#   '.'],
#  ['واوضح',
#   'و',
#   'أوضح',
#   'ان',
#   'رئيس',
#   'الوزراء',
#   '"',
#   'لم',
#   'يكن',
#   'يملك',
#   'الحق',
#   'في',
#   'التخلي',
#   'عن',
#   'القدس',
#   'التي',
#   'ورثها',
#   'ورث',
#   'ها',
#   'الشعب',
#   'اليهودي',
#   '"',
#   'مضيفا',
#   '"',
#   'فهو',
#   'ف',
#   'هو',
#   'لا',
#   'يتمتع',
#   'بائتلاف',
#   'ب',
#   'ائتلاف',
#   'حكومي',
#   'ولا',
#   'و',
#   'لا',
#   'بغالبية',
#   'ب',
#   'غالبية',
#   'في',
#   'البرلمان',
#   'ولا',
#   'و',
#   'لا',
#   'حتى',
#   'دعم',
#   'السكان',
#   '"',
#   '.'],
#  ['وشدد',
#   'و',
#   'شدد',
#   'على',
#   'ان',
#   'الحكومة',
#   'العراقية',
#   '"',
#   'تحتفظ',
#   'بحقها',
#   'ب',
#   'حق',
#   'ها',
#   'الكامل',
#   'والثابت',
#   'و',
#   'الثابت',
#   'الذي',
#   'يكفله',
#   'يكفل',
#   'ه',
#   'لها',
#   'ل',
#   'ها',
#   'ميثاق',
#   'الامم',
#   'المتحدة',
#   'ومبادئ',
#   'و',
#   'مبادئ',
#   'القانون',
#   'الدولي',
#   'والاعراف',
#   'و',
#   'الأعراف',
#   'الدولية',
#   'في',
#   'اتخاذ',
#   'الاجراءات',
#   'اللازمة',
#   'من',
#   'اجل',
#   'الدفاع',
#   'عن',
#   'حرمة',
#   'وسيادة',
#   'و',
#   'سيادة',
#   'ارض',
#   'العراق',
#   'وامن',
#   'و',
#   'أمن',
#   'شعبه',
#   'شعب',
#   'ه',
#   'والمطالبة',
#   'و',
#   'المطالبة',
#   'بالتعويض',
#   'ب',
#   'التعويض',
#   'عن',
#   'الاضرار',
#   'البشرية',
#   'والمادية',
#   'و',
#   'المادية',
#   'والمعنوية',
#   'و',
#   'المعنوية',
#   'التي',
#   'لحقت',
#   'به',
#   'ب',
#   'ه',
#   'جراء',
#   'هذه',
#   'الاعمال',
#   'العدوانية',
#   'طبقا',
#   'لمبدأ',
#   'ل',
#   'مبدإ',
#   'المسؤولية',
#   'الدولية',
#   '"',
#   '.'],
#  ['ويأتى',
#   'و',
#   'يأتي',
#   'نقل',
#   'واستقبال',
#   'و',
#   'استقبال',
#   'المرضى',
#   'والمصابين',
#   'و',
#   'المصابين',
#   'العراقيين',
#   'فى',
#   'مستشفيات',
#   'المملكة',
#   'العربية',
#   'السعودية',
#   'تنفيذا',
#   'لتوجيهات',
#   'ل',
#   'توجيهات',
#   'العاهل',
#   'السعودى',
#   'الملك',
#   'فهد',
#   'بن',
#   'عبدالعزيز',
#   'والامير',
#   'و',
#   'الأمير',
#   'عبد',
#   'الله',
#   'بن',
#   'عبد',
#   'العزيز',
#   'ولى',
#   'العهد',
#   'نائب',
#   'رئيس',
#   'مجلس',
#   'الوزراء',
#   'ورئيس',
#   'و',
#   'رئيس',
#   'الحرس',
#   'الوطنى',
#   'والامير',
#   'و',
#   'الأمير',
#   'سلطان',
#   'بن',
#   'عبد',
#   'العزيز',
#   'النائب',
#   'الثانى',
#   'لرئيس',
#   'ل',
#   'رئيس',
#   'مجلس',
#   'الوزراء',
#   '.'],
#  ['الاتحاد',
#   'الاوروبى',
#   'يساعد',
#   'التلاميذ',
#   'الصينيين',
#   'على',
#   'زيادة',
#   'الادراك',
#   'حول',
#   'حماية',
#   'البيئة'],
#  ['وزير',
#   'التجارة',
#   'العراقي',
#   ':',
#   'العراق',
#   'خسر',
#   'اكثر',
#   'من',
#   '140',
#   'مليار',
#   'دولار',
#   'بسبب',
#   'ب',
#   'سبب',
#   'الحصار'],
#  ['وقال',
#   'و',
#   'قال',
#   'مسؤول',
#   'بالشركة',
#   'ب',
#   'الشركة',
#   'المصرية',
#   'الصينية',
#   'إن',
#   'المشروعات',
#   'التي',
#   'تمت',
#   'الموافقة',
#   'عليها',
#   'علي',
#   'ها',
#   'شملت',
#   'مشروعاً',
#   'لشركة',
#   'ل',
#   'شركة',
#   'شتانج',
#   'الصينية',
#   'لإنتاج',
#   'ل',
#   'إنتاج',
#   'الرخام',
#   'حيث',
#   'تمت',
#   'خصخصة',
#   'مساحة',
#   '132',
#   'ألف',
#   'متر',
#   'مربع',
#   'للشركة',
#   'ل',
#   'الشركة',
#   'كما',
#   'حصلت',
#   'شركة',
#   'السويس',
#   'العقارية',
#   'والمقامة',
#   'و',
#   'المقامة',
#   'برأس',
#   'ب',
#   'رأس',
#   'مال',
#   'مصري',
#   'صيني',
#   'على',
#   'نحو',
#   '67',
#   'ألف',
#   'متر',
#   'مربع',
#   'لإقامة',
#   'ل',
#   'إقامة',
#   'مشروعات',
#   'عليها',
#   'علي',
#   'ها',
#   'في',
#   'مجال',
#   'الملابس',
#   'الجاهزة',
#   'والبطاريات',
#   'و',
#   'البطاريات',
#   '.'],
#  ['بغداد', '،', 'نيويورك', '(', 'الامم', 'المتحدة', ')'],
#  ['وانعكست',
#   'و',
#   'انعكست',
#   'الأزمة',
#   'السياسية',
#   'بين',
#   'كل',
#   'من',
#   'الكويت',
#   'وليبيا',
#   'و',
#   'ليبيا',
#   'من',
#   'جهة',
#   'والجامعة',
#   'و',
#   'الجامعة',
#   'من',
#   'جهة',
#   'أخرى',
#   'على',
#   'زيادة',
#   'تفاقم',
#   'الوضع',
#   'في',
#   'موازنة',
#   'الجامعة',
#   'حيث',
#   'لم',
#   'تسدد',
#   'الدولتان',
#   'حصتهما',
#   'حصة',
#   'هما',
#   'في',
#   'موازنة',
#   'العام',
#   '2003',
#   'وتبلغ',
#   'و',
#   'تبلغ',
#   'حصة',
#   'ليبيا',
#   '4',
#   'ملايين',
#   'و',
#   '200',
#   'ألف',
#   'دولار',
#   'والكويت',
#   'و',
#   'الكويت',
#   '4',
#   'ملايين',
#   'و',
#   '900',
#   'ألف',
#   'دولار',
#   'وتمثلان',
#   'و',
#   'تمثلان',
#   'حوالي',
#   '25',
#   '%',
#   'من',
#   'موازنة',
#   'الجامعة',
#   'وبالرغم',
#   'و',
#   'ب',
#   'الرغم',
#   'من',
#   'عدم',
#   'سداد',
#   'الكويت',
#   'لالتزاماتها',
#   'ل',
#   'التزامات',
#   'ها',
#   'المالية',
#   'تجاه',
#   'الجامعة',
#   'لهذا',
#   'ل',
#   'هٰذا',
#   'العام',
#   'إلا',
#   'أنها',
#   'أن',
#   'ها',
#   'طالبت',
#   'الأمين',
#   'العام',
#   'بتعيين',
#   'ب',
#   'تعيين',
#   'إحدى',
#   'الشخصيات',
#   'الكويتية',
#   'عبد',
#   'الله',
#   'المنصور',
#   'لشغل',
#   'ل',
#   'شغل',
#   'منصب',
#   'أمين',
#   'عام',
#   'مساعد',
#   'للشؤون',
#   'ل',
#   'الشؤون',
#   'المالية',
#   'والإدارية',
#   'و',
#   'الإدارية',
#   'ضمن',
#   'الوظائف',
#   'العليا',
#   'الشاغرة',
#   'في',
#   'جهاز',
#   'الأمانة',
#   'العامة',
#   'إلا',
#   'أن',
#   'موسى',
#   'رأى',
#   'أن',
#   'موضوع',
#   'التعيين',
#   'في',
#   'الوظائف',
#   'العليا',
#   'سيعالج',
#   'س',
#   'يعالج',
#   'في',
#   'قمة',
#   'تونس',
#   'القادمة',
#   'ضمن',
#   'خطة',
#   'إعادة',
#   'هيكلة',
#   'العمل',
#   'العربي',
#   'المشترك',
#   '،',
#   'كما',
#   'أرجأ',
#   'الأمين',
#   'العام',
#   'الامتحانات',
#   'التي',
#   'كان',
#   'من',
#   'المفترض',
#   'أن',
#   'تتم',
#   'في',
#   'شهر',
#   'أكتوبر',
#   'الحالي',
#   'لشغل',
#   'ل',
#   'شغل',
#   'درجات',
#   'شاغرة',
#   'في',
#   'جهاز',
#   'الأمانة',
#   'العامة',
#   'والتي',
#   'و',
#   'التي',
#   'تقدم',
#   'لشغلها',
#   'ل',
#   'شغل',
#   'ها',
#   'أكثر',
#   'من',
#   '2000',
#   'شخص',
#   'من',
#   'مختلف',
#   'الدول',
#   'العربية',
#   '.'],
#  ['واضاف',
#   'و',
#   'أضاف',
#   '"',
#   'ان',
#   'ايا',
#   'من',
#   'ذلك',
#   'ليس',
#   'غلطة',
#   'الفلسطينيين',
#   '.',
#   'ولكن',
#   'و',
#   'لٰكن',
#   'اذا',
#   'كان',
#   'التصور',
#   'انهم',
#   'أن',
#   'هم',
#   'كانوا',
#   'منتفعين',
#   'من',
#   'الحكومة',
#   'السابقة',
#   '،',
#   'فقد',
#   'ف',
#   'قد',
#   'يعانون',
#   'نتيجة',
#   'لذلك',
#   'ل',
#   'ذٰلك',
#   '.',
#   'وهذا',
#   'و',
#   'هٰذا',
#   'من',
#   'بين',
#   'الاسباب',
#   'التى',
#   'تدعونا',
#   'تدعو',
#   'نا',
#   'للعودة',
#   'ل',
#   'العودة',
#   'الى',
#   'بغداد',
#   'سريعا',
#   'بقدر',
#   'ب',
#   'قدر',
#   'ما',
#   'يسمح',
#   'به',
#   'ب',
#   'ه',
#   'الوضع',
#   'الامنى',
#   '"',
#   '.'],
#  ['كما',
#   'تحدث',
#   'سينها',
#   'مع',
#   'وزير',
#   'الخارجية',
#   'البريطانى',
#   'جاك',
#   'سترو',
#   '،',
#   'ووزير',
#   'و',
#   'وزير',
#   'الخارجية',
#   'الروسى',
#   'ايجور',
#   'ايفانوف',
#   'بعد',
#   'فترة',
#   'قصيرة',
#   'من',
#   'اعلان',
#   'فاجبايى',
#   'فى',
#   'البرلمان',
#   'امس',
#   'الجمعة',
#   '.'],
#  ['أسعد',
#   'أيامك',
#   'أيام',
#   'ك',
#   'هذا',
#   'الأسبوع',
#   'هو',
#   'يوم',
#   'الثلاثاء',
#   '.'],
#  ['أما',
#   'محمد',
#   'أوزالب',
#   'ـ',
#   'الخبير',
#   'المصرفي',
#   'ـ',
#   'فيرى',
#   'ف',
#   'يرى',
#   'أن',
#   'هبوط',
#   'الدولار',
#   'بهذا',
#   'ب',
#   'هٰذا',
#   'الشكل',
#   'أمام',
#   'اليورو',
#   'والعملات',
#   'و',
#   'العملات',
#   'الدولية',
#   'الأخرى',
#   '،',
#   'غير',
#   'مبرر',
#   '.'],
#  ['وأوضحوا',
#   'و',
#   'أوضحوا',
#   'أن',
#   'هذه',
#   'الإجراءات',
#   'قد',
#   'تؤدي',
#   'لضغوط',
#   'ل',
#   'ضغوط',
#   'جديدة',
#   'تدفع',
#   'سوق',
#   'الصرف',
#   'المصرية',
#   'لمواجهة',
#   'ل',
#   'مواجهة',
#   'أزمات',
#   'دولارية',
#   'جديدة',
#   '.'],
#  ['بغداد',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'ذكرت',
#   'الامم',
#   'المتحدة',
#   'ان',
#   'قيمة',
#   'صادرات',
#   'النفط',
#   'العراقية',
#   'بلغت',
#   '32',
#   'مليار',
#   'دولار',
#   '،',
#   'اي',
#   'بواقع',
#   'ب',
#   'واقع',
#   'اكثر',
#   'من',
#   '1،9',
#   'مليون',
#   'برميل',
#   'يوميا',
#   '،',
#   'منذ',
#   'بدء',
#   'العمل',
#   'ببرنامج',
#   'ب',
#   'برنامج',
#   '"',
#   'النفط',
#   'مقابل',
#   'الغذاء',
#   '"',
#   'في',
#   'نهاية',
#   '1996',
#   '.'],
#  ['حصلت',
#   'المشاركة',
#   'المنتظرة',
#   'لمدة',
#   'ل',
#   'مدة',
#   'طويلة',
#   'لشركة',
#   'ل',
#   'شركة',
#   'تشاينا',
#   'ايرلاينز',
#   'التايوانية',
#   'فى',
#   'شركة',
#   'الطيران',
#   'الصينية',
#   'للبضائع',
#   'ل',
#   'البضائع',
#   'بالبر',
#   'ب',
#   'البر',
#   'الصينى',
#   'على',
#   'الموافقة',
#   'من',
#   'قبل',
#   'مجلس',
#   'الدولة',
#   '/',
#   'مجلس',
#   'الوزراء',
#   '/',
#   'الصينى',
#   '.'],
#  ['أعلن',
#   'ذلك',
#   'الدكتور',
#   'مصطفى',
#   'أحمد',
#   'المستشار',
#   'بالمعهد',
#   'ب',
#   'المعهد',
#   '.'],
#  ['ولم',
#   'و',
#   'لم',
#   'يتم',
#   'اعتقال',
#   'احد',
#   'بحسب',
#   'ب',
#   'حسب',
#   'المتحدث',
#   'باسم',
#   'ب',
#   'اسم',
#   'الشرطة',
#   '.'],
#  ['واعتبر',
#   'و',
#   'اعتبر',
#   'ان',
#   'القرار',
#   'الذي',
#   'اتخذه',
#   'اتخذ',
#   'ه',
#   'منظمة',
#   'الدول',
#   'المصدرة',
#   'للنفط',
#   'ل',
#   'النفط',
#   'بزيادةانتاجها',
#   '800',
#   'الف',
#   'برميل',
#   'يوميا',
#   'والاجراءات',
#   'و',
#   'الإجراءات',
#   'التي',
#   'اتخذت',
#   'منذ',
#   'ذلك',
#   'الحين',
#   '"',
#   'ليست',
#   'كافية',
#   'حتى',
#   'الان',
#   'للسماح',
#   'ل',
#   'السماح',
#   'للاسواق',
#   'ل',
#   'الأسواق',
#   'باستيعاب',
#   'ب',
#   'استيعاب',
#   '"',
#   'الوضع',
#   'الجديد',
#   '.'],
#  ['ولكن',
#   'و',
#   'لٰكن',
#   'مصدراً',
#   'مسئولا',
#   'بمجلس',
#   'ب',
#   'مجلس',
#   'الوزراء',
#   'أكد',
#   'في',
#   'تصريحات',
#   'خاصة',
#   'عدم',
#   'صحة',
#   'ذلك',
#   '،',
#   'وأن',
#   'و',
#   'أن',
#   'رئيس',
#   'الوزراء',
#   'لم',
#   'يتلق',
#   'أي',
#   'مذكرة',
#   'من',
#   'المهندس',
#   'أحمد',
#   'عز',
#   'بشأن',
#   'ب',
#   'شأن',
#   'زيادة',
#   'أسعار',
#   'حديد',
#   'التسليح',
#   '،',
#   'وأن',
#   'و',
#   'أن',
#   'أحمد',
#   'عز',
#   'يحدد',
#   'أسعار',
#   'الحديد',
#   'وفقاً',
#   'لظروف',
#   'ل',
#   'ظروف',
#   'وتكاليف',
#   'و',
#   'تكاليف',
#   'الإنتاج',
#   'في',
#   'شركاته',
#   'شركات',
#   'ه',
#   'والأسعار',
#   'و',
#   'الأسعار',
#   'العالمية',
#   '،',
#   'ومن',
#   'و',
#   'من',
#   'ثم',
#   'لا',
#   'يمكن',
#   'لأي',
#   'ل',
#   'أي',
#   'مسئول',
#   'حكومي',
#   'أن',
#   'يتدخل',
#   'في',
#   'منظومة',
#   'تحديد',
#   'الأسعار',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'راشد',
#   'إن',
#   'الشركات',
#   'العالمية',
#   'بررت',
#   'زيادة',
#   'رسوم',
#   'الشحن',
#   'بارتفاع',
#   'ب',
#   'ارتفاع',
#   'أسعار',
#   'الوقود',
#   'وتغطية',
#   'و',
#   'تغطية',
#   'خدمات',
#   'الأمان',
#   'على',
#   'طائراتها',
#   'طائرات',
#   'ها',
#   '.'],
#  ['وأشار',
#   'و',
#   'أشار',
#   'إلى',
#   'أن',
#   'جميع',
#   'مرضى',
#   'سارس',
#   'فى',
#   '13',
#   'مقاطعة',
#   'منها',
#   'من',
#   'ها',
#   'لياونينج',
#   'وانخوى',
#   'وشهجيانج',
#   'أصيبوا',
#   'بعدوى',
#   'ب',
#   'عدوى',
#   'المرض',
#   'خارج',
#   'المناطق',
#   'التى',
#   'يقيمون',
#   'فيها',
#   'في',
#   'ها',
#   '.'],
#  ['ويغيب',
#   'و',
#   'يغيب',
#   'رضوان',
#   'حاليا',
#   'عن',
#   'مباريات',
#   'هانزا',
#   'بسبب',
#   'ب',
#   'سبب',
#   'تمزق',
#   'في',
#   'الرباط',
#   'الصليبي',
#   '،',
#   'وهو',
#   'و',
#   'هو',
#   'يأمل',
#   'بان',
#   'ب',
#   'أن',
#   'يتماثل',
#   'للشفاء',
#   'ل',
#   'الشفاء',
#   'خلال',
#   'فترة',
#   'لا',
#   'تتجاوز',
#   'الشهر',
#   'لمعاودة',
#   'ل',
#   'معاودة',
#   'اللعب',
#   'مع',
#   'زملائه',
#   'زملاء',
#   'ه',
#   '.'],
#  ['كشف',
#   'مسؤولون',
#   'أمريكيون',
#   'أن',
#   'إدارة',
#   'الرئيس',
#   'الأمريكي',
#   'جورج',
#   'بوش',
#   'أقرت',
#   'تشكيل',
#   'وكالة',
#   'استخبارات',
#   'عراقية',
#   'للتجسس',
#   'ل',
#   'التجسس',
#   '.'],
#  ['وشدد',
#   'و',
#   'شدد',
#   'وزير',
#   'الداخلية',
#   'الباكستاني',
#   '،',
#   'في',
#   'لقائه',
#   'لقاء',
#   'ه',
#   'الصحافيين',
#   'في',
#   'كراتشي',
#   '،',
#   'على',
#   'نية',
#   'الحكومة',
#   'العمل',
#   'على',
#   'تنظيم',
#   'المدارس',
#   'الدينية',
#   '،',
#   'مؤكداً',
#   'أن',
#   'المدارس',
#   'التي',
#   'تمنح',
#   'درجة',
#   'معينة',
#   'وتعترف',
#   'و',
#   'تعترف',
#   'بها',
#   'ب',
#   'ها',
#   'الحكومة',
#   'هي',
#   'التي',
#   'سيسمح',
#   'س',
#   'يسمح',
#   'لها',
#   'ل',
#   'ها',
#   'بالبقاء',
#   'ب',
#   'البقاء',
#   'والعمل',
#   'و',
#   'العمل',
#   '.'],
#  ['عدم',
#   'استقرار',
#   'أسعار',
#   'مواد',
#   'البناء',
#   'تصيب',
#   'سوق',
#   'العقارات',
#   'بالشلل',
#   'بالشلل'],
#  ['وأشار',
#   'و',
#   'أشار',
#   'التقرير',
#   'أيضا',
#   'إلى',
#   'أن',
#   'المقاعد',
#   'البرلمانية',
#   'التي',
#   'تشغلها',
#   'تشغل',
#   'ها',
#   'النساء',
#   'في',
#   'الهيئات',
#   'التشريعية',
#   'العربية',
#   'لم',
#   'تتجاوز',
#   '5',
#   '%',
#   'من',
#   'إجماليها',
#   'إجمالي',
#   'ها',
#   '.'],
#  ['وقد',
#   'و',
#   'قد',
#   'اختير',
#   'هذا',
#   'الاسم',
#   '"',
#   'العالمي',
#   '"',
#   'للتنظيم',
#   'ل',
#   'التنظيم',
#   '،',
#   'كونه',
#   'كون',
#   'ه',
#   'يضم',
#   'قسماً',
#   'من',
#   'الليبيين',
#   'الذين',
#   'هاجروا',
#   'من',
#   'إسرائيل',
#   'ويعيشون',
#   'و',
#   'يعيشون',
#   'اليوم',
#   'في',
#   'دول',
#   'أوروبية',
#   'أخرى',
#   '،',
#   'خصوصاً',
#   'فرنسا',
#   'وإيطاليا',
#   'و',
#   'إيطاليا',
#   '.'],
#  ['فذكروا',
#   'ف',
#   'ذكروا',
#   'أنهم',
#   'أن',
#   'هم',
#   'اتفقوا',
#   'فيما',
#   'في',
#   'ما',
#   'بينهم',
#   'بين',
#   'هم',
#   'على',
#   'القيام',
#   'بحفريات',
#   'ب',
#   'حفريات',
#   'في',
#   'ذلك',
#   'الموقع',
#   'لاعتقادهم',
#   'ل',
#   'اعتقاد',
#   'هم',
#   'بوجود',
#   'ب',
#   'وجود',
#   'كنز',
#   'ثمين',
#   'مدفون',
#   'فيه',
#   'في',
#   'ه',
#   'واعترف',
#   'و',
#   'اعترف',
#   'المظنون',
#   'فيهم',
#   'في',
#   'هم',
#   'الأربع',
#   '(',
#   'أحدهم',
#   'أحد',
#   'هم',
#   'أصيل',
#   'مدينة',
#   'قابس',
#   'واثنان',
#   'و',
#   'اثنان',
#   'من',
#   'القصرين',
#   'ورابعهم',
#   'و',
#   'رابع',
#   'هم',
#   'من',
#   'الهوارية',
#   ')',
#   'أنهم',
#   'أن',
#   'هم',
#   'تجمعوا',
#   'داخل',
#   'الضيعة',
#   'وباشروا',
#   'و',
#   'باشروا',
#   'عملهم',
#   'عمل',
#   'هم',
#   'تحت',
#   'جنح',
#   'الظلام',
#   'خشية',
#   'أن',
#   'يفتضح',
#   'أمرهم',
#   'أمر',
#   'هم',
#   'غير',
#   'أن',
#   'ما',
#   'خشوا',
#   'وقوعه',
#   'وقوع',
#   'ه',
#   'حصل',
#   '.'],
#  ['واضاف',
#   'و',
#   'أضاف',
#   'خاتمى',
#   'انه',
#   'أن',
#   'ه',
#   '"',
#   'يجب',
#   'تحقيق',
#   'الديمقراطية',
#   'من',
#   'خلال',
#   'مشاركة',
#   'جميع',
#   'المجموعات',
#   'الدينية',
#   'والعرقية',
#   'و',
#   'العرقية',
#   '"',
#   '.'],
#  ['أكد',
#   'تقرير',
#   'أعدته',
#   'أعدت',
#   'ه',
#   'لجنة',
#   'التعليم',
#   'بمجلس',
#   'ب',
#   'مجلس',
#   'الشعب',
#   'أن',
#   'تكلفة',
#   'الإنفاق',
#   'على',
#   'الدروس',
#   'الخصوصية',
#   'يتراوح',
#   'بين',
#   '7',
#   'و',
#   '12',
#   'مليار',
#   'جنيه',
#   'سنوياً',
#   'وتتسبب',
#   'و',
#   'تتسبب',
#   'هذه',
#   'الظاهرة',
#   'في',
#   'تهميش',
#   'دور',
#   'المدرسة',
#   'النظامية',
#   'وتهدد',
#   'و',
#   'تهدد',
#   'المؤسسة',
#   'التعليمية',
#   'بأسرها',
#   'ب',
#   'أسر',
#   'ها',
#   '،',
#   'وتسبب',
#   'و',
#   'تسبب',
#   'انعدام',
#   'ثقة',
#   'المواطن',
#   'في',
#   'قدرة',
#   'النظام',
#   'التربوي',
#   '،',
#   'وتفريغ',
#   'و',
#   'تفريغ',
#   'عملية',
#   'مجانية',
#   'التعليم',
#   'من',
#   'مضمونها',
#   'مضمون',
#   'ها',
#   '،',
#   'وضياع',
#   'و',
#   'ضياع',
#   'جزء',
#   'من',
#   'موازنة',
#   'الدولة',
#   'من',
#   'دون',
#   'نفع',
#   '،',
#   'والانحدار',
#   'و',
#   'الانحدار',
#   'نحو',
#   'هاوية',
#   'التجارة',
#   'بالتعليم',
#   'ب',
#   'التعليم',
#   'مما',
#   'من',
#   'ما',
#   'يؤدي',
#   'لانهيار',
#   'ل',
#   'انهيار',
#   'مبدأ',
#   'تكافؤ',
#   'الفرص',
#   'وما',
#   'و',
#   'ما',
#   'يصاحب',
#   'ذلك',
#   'من',
#   'سلوكيات',
#   'وتداعيات',
#   'و',
#   'تداعيات',
#   'تهدد',
#   'السلام',
#   'الاجتماعي',
#   'للوطن',
#   'ل',
#   'الوطن',
#   '.'],
#  ['وأكدت',
#   'و',
#   'أكدت',
#   'مصادر',
#   'مسئولية',
#   'بوزارة',
#   'ب',
#   'وزارة',
#   'التعاون',
#   'الدولي',
#   'أن',
#   'الحساب',
#   'المجمد',
#   'يمثل',
#   'أقساط',
#   'الديون',
#   'التي',
#   'ألغاها',
#   'ألغى',
#   'ها',
#   'نادي',
#   'باريس',
#   '.'],
#  ['أما',
#   'المبلغ',
#   'الباقي',
#   'والبالغ',
#   'و',
#   'البالغ',
#   'قيمته',
#   'قيمة',
#   'ه',
#   '5',
#   'مليارات',
#   'و',
#   '502',
#   'مليون',
#   'جنيه',
#   'فقام',
#   'ف',
#   'قام',
#   '"',
#   'المركزي',
#   '"',
#   'بسحبه',
#   'ب',
#   'سحب',
#   'ه',
#   'عن',
#   'طريق',
#   '4',
#   'ودائع',
#   'تم',
#   'طرحها',
#   'طرح',
#   'ها',
#   'على',
#   'البنوك',
#   '.'],
#  ['وصرحت',
#   'و',
#   'صرحت',
#   'المتحدثة',
#   'باسم',
#   'ب',
#   'اسم',
#   'المفوضية',
#   'رون',
#   'ريدموند',
#   'فى',
#   'مؤتمر',
#   'صحفى',
#   'ان',
#   'المفوضية',
#   'بعثت',
#   'بقافلة',
#   'ب',
#   'قافلة',
#   'مساعدات',
#   'للاسهام',
#   'ل',
#   'الإسهام',
#   'فى',
#   'توفير',
#   'الاحتياجات',
#   'العاجلة',
#   'للاجئين',
#   'ل',
#   'اللاجئين',
#   'الفلسطينيين',
#   'فى',
#   'العاصمة',
#   'العراقية',
#   '.'],
#  ['وعلى',
#   'و',
#   'على',
#   'متن',
#   'الغواصة',
#   '"',
#   'كورسك',
#   '"',
#   'مسؤولون',
#   'كبار',
#   'في',
#   'هيئة',
#   'اركان',
#   'البحرية',
#   'حسبما',
#   'افاد',
#   'الناطق',
#   'باسم',
#   'ب',
#   'اسم',
#   'البحرية',
#   'الروسية',
#   'الذي',
#   'كان',
#   'يتحدث',
#   'لاذاعة',
#   'ل',
#   'إذاعة',
#   '"',
#   'اصداء',
#   'موسكو',
#   '"',
#   '.'],
#  ['واوضح',
#   'و',
#   'أوضح',
#   'رئيس',
#   'الاتحاد',
#   'ادريان',
#   'والاس',
#   'اليوم',
#   'الخميس',
#   'ان',
#   'اوتي',
#   '،',
#   'التي',
#   'حلت',
#   'رابعة',
#   'في',
#   'سباق',
#   '100',
#   'م',
#   'خلال',
#   'تجارب',
#   'انتقاء',
#   'المنتخب',
#   'في',
#   '22',
#   'تموز',
#   '/',
#   'يوليو',
#   'الماضي',
#   '،',
#   'لن',
#   'تستطيع',
#   'المشاركة',
#   'في',
#   'دورة',
#   'الالعاب',
#   'الاولمبية',
#   'الا',
#   'في',
#   'احدى',
#   'الحالات',
#   'الثلاث',
#   ':',
#   'انسحاب',
#   'صاحبة',
#   'احدى',
#   'المراكز',
#   'الثلاثة',
#   'الاولى',
#   'او',
#   'اصابتها',
#   'إصابة',
#   'ها',
#   'او',
#   'عدم',
#   'قدرتها',
#   'قدرة',
#   'ها',
#   'على',
#   'المحافظة',
#   'على',
#   'مستواها',
#   'مستوى',
#   'ها',
#   '.'],
#  ['وكان',
#   'و',
#   'كان',
#   'نتنياهو',
#   'قد',
#   'قال',
#   'إنه',
#   'إن',
#   'ه',
#   'يأمل',
#   'في',
#   'منافسة',
#   'قناة',
#   'السويس',
#   'بمد',
#   'ب',
#   'مد',
#   'خط',
#   'لسكك',
#   'ل',
#   'سكك',
#   'الحديد',
#   'بين',
#   'ميناء',
#   'اشدود',
#   'غرب',
#   'القدس',
#   'المحتلة',
#   'ومرفأ',
#   'و',
#   'مرفإ',
#   'إيلات',
#   'في',
#   'جنوب',
#   'إسرائيل',
#   '.'],
#  ['وكان',
#   'و',
#   'كان',
#   'مقرراً',
#   'تنفيذ',
#   'العملية',
#   'منذ',
#   'كانون',
#   'الثاني',
#   '(',
#   'يناير',
#   ')',
#   '2000',
#   'وتأجلت',
#   'و',
#   'تأجلت',
#   'إلى',
#   'نيسان',
#   '(',
#   'ابريل',
#   ')',
#   '_',
#   'ثم',
#   'الى',
#   'آيار',
#   '(',
#   'مايو',
#   ')',
#   'من',
#   'العام',
#   'نفسه',
#   'نفس',
#   'ه',
#   '،',
#   'ثم',
#   'إلى',
#   'نيسان',
#   'الماضي',
#   'وجاءت',
#   'و',
#   'جاءت',
#   'احداث',
#   'أيلول',
#   '(',
#   'سبتمبر',
#   ')',
#   'ليكون',
#   'ل',
#   'يكون',
#   'التأجيل',
#   'أكيداً',
#   '.'],
#  ['أوضح',
#   'أن',
#   'إجمالي',
#   'الموزع',
#   'من',
#   'الأقطان',
#   'المصرية',
#   'ما',
#   'بين',
#   'ارتباطات',
#   'التصدير',
#   'وتسليمات',
#   'و',
#   'تسليمات',
#   'المغازل',
#   'المحلية',
#   'بلغ',
#   '2.3',
#   'مليون',
#   'قنطار',
#   'متري',
#   'شعر',
#   'بنسبة',
#   'ب',
#   'نسبة',
#   '50',
#   '%',
#   'من',
#   'إجمالي',
#   'القطن',
#   'المتداول',
#   'المعروض',
#   'خلال',
#   'الموسم',
#   'الحالي',
#   '.'],
#  ['وبدا',
#   'و',
#   'بدا',
#   'الحضور',
#   'الكثيف',
#   'للمسؤولين',
#   'ل',
#   'المسؤولين',
#   'علامة',
#   'بارزة',
#   'على',
#   'الحرص',
#   'على',
#   'ألا',
#   'أن',
#   'لا',
#   'تؤثر',
#   'أحداث',
#   'عارضة',
#   'على',
#   'استمرار',
#   'شنودة',
#   'في',
#   'إقامة',
#   'الإفطار',
#   'التقليدي',
#   'السنوي',
#   'الذي',
#   'بدأه',
#   'بدأ',
#   'ه',
#   'قبل',
#   'نحو',
#   '19',
#   'عاما',
#   '.'],
#  ['قال',
#   'اللواء',
#   'مجدي',
#   'القبيصي',
#   'رئيس',
#   'الجهاز',
#   'التنفيذي',
#   'للهيئة',
#   'ل',
#   'الهيئة',
#   ':',
#   'إن',
#   'هذه',
#   'المراكز',
#   'تشمل',
#   '24',
#   'مركزاً',
#   'في',
#   'البحر',
#   'الأحمر',
#   'و',
#   '7',
#   'مراكز',
#   'في',
#   'العين',
#   'السخنة',
#   'و',
#   '7',
#   'مراكز',
#   'في',
#   'رأس',
#   'سدر',
#   'و',
#   '12',
#   'مركزاً',
#   'في',
#   'خليج',
#   'العقبة',
#   '.'],
#  ['احتجاز', 'سفينة', 'بضائع', 'ماليزية', 'فى', 'شنتشن'],
#  ['واشار',
#   'و',
#   'أشار',
#   'عبيد',
#   'الى',
#   'انه',
#   'أن',
#   'ه',
#   'ليس',
#   'هناك',
#   'سلام',
#   'جزئى',
#   'او',
#   'سلام',
#   'من',
#   'جانب',
#   'واحد',
#   'ويجب',
#   'و',
#   'يجب',
#   'تحقيق',
#   'سلام',
#   'شامل',
#   'مؤكدا',
#   'على',
#   'ان',
#   'الامن',
#   'لن',
#   'يتحقق',
#   'ويضمن',
#   'و',
#   'يضمن',
#   'الا',
#   'بعد',
#   'تحقيق',
#   'السلام',
#   'وان',
#   'و',
#   'أن',
#   'السلام',
#   'لايمكن',
#   'لا',
#   'يمكن',
#   'تحقيقه',
#   'تحقيق',
#   'ه',
#   'الا',
#   'على',
#   'اساس',
#   'العدالة',
#   'والمساواة',
#   'و',
#   'المساواة',
#   '.'],
#  ['روما',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'وصل',
#   'البابا',
#   'يوحنا',
#   'بولس',
#   'الثاني',
#   'نحو',
#   'الساعة',
#   '18،00',
#   '(',
#   '16،00',
#   'تغ',
#   ')',
#   'الى',
#   'كنيسة',
#   'القديس',
#   'يوحنا',
#   'في',
#   'روما',
#   'على',
#   'متن',
#   'سيارته',
#   'سيارة',
#   'ه',
#   'الزجاجية',
#   'للمشاركة',
#   'ل',
#   'المشاركة',
#   'في',
#   'افتتاح',
#   'الايام',
#   'العالمية',
#   'ال',
#   '15',
#   'للشباب',
#   'ل',
#   'الشباب',
#   '.'],
#  ['وقدمت',
#   'و',
#   'قدمت',
#   'السعودية',
#   '550',
#   'مليون',
#   'دولار',
#   'من',
#   'المساعدات',
#   'الى',
#   'البوسنه',
#   'بينها',
#   'بين',
#   'ها',
#   '120',
#   'مليونا',
#   'من',
#   'المساعدة',
#   'المباشرة',
#   'الى',
#   'حكومتها',
#   'حكومة',
#   'ها',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'إن',
#   'الاستثمارات',
#   'الأجنبية',
#   'المرشحة',
#   'للمجيء',
#   'ل',
#   'المجيء',
#   'إلى',
#   'العراق',
#   'مؤجلة',
#   'حالياً',
#   'بسبب',
#   'ب',
#   'سبب',
#   'تداعيات',
#   'الوضع',
#   'الأمني',
#   'الراهن',
#   '.'],
#  ['واعتبر',
#   'و',
#   'اعتبر',
#   'شعراوي',
#   'ان',
#   'الفاعليات',
#   'التي',
#   'أظهرت',
#   'مقاومة',
#   'لمنظمة',
#   'ل',
#   'منظمة',
#   'التجارة',
#   'الدولية',
#   'في',
#   'اجتماعات',
#   'دافوس',
#   'وسياتل',
#   'و',
#   'سياتل',
#   'وجنوى',
#   'جاءت',
#   'بمثابة',
#   'ب',
#   'مثابة',
#   '»',
#   'دليل',
#   'قوي',
#   'وفاعل',
#   'و',
#   'فاعل',
#   'على',
#   'إمكان',
#   'مواجهة',
#   'محاولات',
#   'الرأسمالية',
#   'العالمية',
#   'للسيطرة',
#   'ل',
#   'السيطرة',
#   'على',
#   'الشعوب',
#   'وهو',
#   'و',
#   'هو',
#   'ما',
#   'يقتضي',
#   'درس',
#   'هذه',
#   'التجارب',
#   'وتطويرها',
#   'و',
#   'تطوير',
#   'ها',
#   'لحماية',
#   'ل',
#   'حماية',
#   'استقلال',
#   'الجنوب',
#   'وتحقيق',
#   'و',
#   'تحقيق',
#   'تطلعاته',
#   'تطلعات',
#   'ه',
#   'في',
#   'التنمية',
#   'والتقدم',
#   'و',
#   'التقدم',
#   'والرفاهية',
#   'و',
#   'الرفاهية',
#   '«',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'كوتاري',
#   'إن',
#   'إجمالي',
#   'عائدات',
#   'الهند',
#   'من',
#   'صناعة',
#   'الحلي',
#   'تبلغ',
#   '59',
#   'مليار',
#   'دولار',
#   'و',
#   '80',
#   '%',
#   'منها',
#   'من',
#   'ها',
#   'من',
#   'صناعة',
#   'الماس',
#   'حيث',
#   'يستحوذ',
#   'السوق',
#   'الهندي',
#   'على',
#   '60',
#   '%',
#   'من',
#   'سوق',
#   'قيمة',
#   'الماسات',
#   'العالمية',
#   'و',
#   '85',
#   '%',
#   'من',
#   'الكمية',
#   'و',
#   '92',
#   '%',
#   'من',
#   'عدد',
#   'قطع',
#   'الماس',
#   'المتداولة',
#   'بالعالم',
#   'ب',
#   'العالم',
#   '.'],
#  ['ودخل',
#   'و',
#   'دخل',
#   'الحزب',
#   'في',
#   'مفاوضات',
#   'مع',
#   'الادارة',
#   '،',
#   'انتهت',
#   'الى',
#   'موافقته',
#   'موافقة',
#   'ه',
#   'على',
#   'تعديل',
#   'بعض',
#   'الفقرات',
#   '،',
#   'خاصة',
#   'من',
#   'حيث',
#   'الصيغة',
#   'مع',
#   'الحفاظ',
#   'على',
#   'موقف',
#   'الحزب',
#   '.'],
#  ['هذا',
#   'وان',
#   'و',
#   'إن',
#   'السيارات',
#   'التى',
#   'تخص',
#   'بعض',
#   'شركات',
#   'سيارات',
#   'الاجرة',
#   'الصغيرة',
#   'اكتشف',
#   'انها',
#   'أن',
#   'ها',
#   'من',
#   'دون',
#   'علامات',
#   'بالالوان',
#   'ب',
#   'الألوان',
#   'المطلوبة',
#   'وعلى',
#   'و',
#   'على',
#   'الفور',
#   'تم',
#   'تعقيمها',
#   'تعقيم',
#   'ها',
#   '.'],
#  ['واضافت',
#   'و',
#   'أضافت',
#   'الوكالة',
#   'ان',
#   'الامير',
#   'نايف',
#   'عقد',
#   'على',
#   'الاثر',
#   'اجتماعا',
#   'مغلقا',
#   'مع',
#   'وزير',
#   'الداخلية',
#   'اليمني',
#   'حسين',
#   'محمد',
#   'عرب',
#   '.'],
#  ['أسعد', 'أيامك', 'أيام', 'ك', 'هذا', 'الأسبوع', 'هو', 'يوم', 'الاثنين', '!'],
#  ['والقى',
#   'و',
#   'ألقى',
#   'مونس',
#   'كلمة',
#   'قال',
#   'فيها',
#   'في',
#   'ها',
#   ':',
#   '"',
#   'ان',
#   'بطاركة',
#   'الشرق',
#   'حملوا',
#   'دوما',
#   'هم',
#   'هذا',
#   'الشرق',
#   'في',
#   'قضاياه',
#   'قضايا',
#   'ه',
#   'مع',
#   'الله',
#   'والانسان',
#   'و',
#   'الإنسان',
#   'وقيم',
#   'و',
#   'قيم',
#   'الحرية',
#   'والكرامة',
#   'و',
#   'الكرامة',
#   'والسلام',
#   'و',
#   'السلام',
#   'والعيش',
#   'و',
#   'العيش',
#   'معا',
#   'لان',
#   'محبة',
#   'الآخرين',
#   'واحترامهم',
#   'و',
#   'احترام',
#   'هم',
#   'وبناء',
#   'و',
#   'بناء',
#   'مستقبل',
#   'مشترك',
#   'هي',
# ...
#   '"',
#   'جاء',
#   'فيه',
#   'في',
#   'ه',
#   ':',
#   '"',
#   'خسر',
#   'رئيس',
#   'الحكومة',
#   'امس',
#   'انجازا',
#   'سياسيا',
#   'عزيزا',
#   'علي',
#   'قلبه',
#   'قلب',
#   'ه',
#   '،',
#   'حكومة',
#   'وحدة',
#   'وطنية',
#   'حافظ',
#   'عليها',
#   'علي',
#   'ها',
#   'ورعاها',
#   'و',
#   'رعى',
#   'ها',
#   'منذ',
#   'انتخابه',
#   'انتخاب',
#   'ه',
#   '،',
#   'سقطت',
#   'امس',
#   'بعد',
#   '20',
#   'شهرا',
#   '.'],
#  ['من',
#   'المتوقع',
#   'ان',
#   'تظهر',
#   '33',
#   'حافلة',
#   'اخرى',
#   'تستخدم',
#   'غاز',
#   'البترول',
#   'المسال',
#   'فى',
#   'شوارع',
#   'هذه',
#   'المنطقة',
#   'الاقتصادية',
#   'الخاصة',
#   'فى',
#   'وقت',
#   'لاحق',
#   'من',
#   'هذا',
#   'العام',
#   '.'],
#  ['انديانابوليس',
#   '(',
#   'الولايات',
#   'المتحدة',
#   ')',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'بلغ',
#   'المغربي',
#   'يونس',
#   'العيناوي',
#   'المرحلة',
#   'الثانية',
#   'من',
#   'دورة',
#   'انديانابوليس',
#   'الاميركية',
#   'الدولية',
#   'لكرة',
#   'ل',
#   'كرة',
#   'المضرب',
#   'البالغة',
#   'جوائزها',
#   'جوائز',
#   'ها',
#   '800',
#   'الف',
#   'دولار',
#   'بفوزه',
#   'ب',
#   'فوز',
#   'ه',
#   'على',
#   'السويدي',
#   'توماس',
#   'يوهانسون',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '4',
#   ')',
#   'و',
#   '6',
#   '-',
#   '4',
#   '.'],
#  ['تونس',
#   '/',
#   'الصباح',
#   'يبدو',
#   'ان',
#   'ما',
#   'يشبه',
#   'عدم',
#   'التنسيق',
#   'حصل',
#   'بين',
#   'دوائر',
#   'القرار',
#   'صلب',
#   'الحزب',
#   'الديموقراطي',
#   'التقدمي',
#   '،',
#   'فيما',
#   'في',
#   'ما',
#   'يخص',
#   'البيان',
#   'الانتخابي',
#   'والتعديلات',
#   'و',
#   'التعديلات',
#   'التي',
#   'حصلت',
#   'مفاوضات',
#   'بشأنها',
#   'ب',
#   'شأن',
#   'ها',
#   'بين',
#   'الحزب',
#   'والادارة',
#   'و',
#   'الإدارة',
#   '.'],
#  ['وبرأت',
#   'و',
#   'برأت',
#   'لجنة',
#   'التحكيم',
#   'في',
#   'الاتحاد',
#   'الدولي',
#   'اوتي',
#   'من',
#   'تهمة',
#   'تناول',
#   'المنشطات',
#   'في',
#   '3',
#   'تموز',
#   '/',
#   'يوليو',
#   'الماضي',
#   'لعدم',
#   'ل',
#   'عدم',
#   'وجود',
#   'ادلة',
#   'تثبت',
#   'تعاطيها',
#   'تعاطي',
#   'ها',
#   'موادا',
#   'ممنوعة',
#   'اي',
#   'بعد',
#   'نحو',
#   '11',
#   'شهرا',
#   'من',
#   'آخر',
#   'تجربة',
#   'لها',
#   'ل',
#   'ها',
#   'في',
#   '7',
#   'آب',
#   '/',
#   'اغسطس',
#   '1999',
#   'في',
#   'لقاء',
#   'هيتشتل',
#   'البلجيكي',
#   'حيث',
#   'احرزت',
#   'المركز',
#   'الاول',
#   'في',
#   'سباقي',
#   '100',
#   'م',
#   '(',
#   '99',
#   'ر',
#   '10',
#   'ثوان',
#   ')',
#   'و',
#   '200',
#   'م',
#   '(',
#   '43',
#   'ر',
#   '22',
#   'ث',
#   ')',
#   '.'],
#  ['فقد',
#   'ف',
#   'قد',
#   'جاءت',
#   'دعوة',
#   'الكلدان',
#   'والآشوريين',
#   'و',
#   'الأشوريين',
#   'هذه',
#   'بعد',
#   'سلسلة',
#   'مطالب',
#   'كان',
#   'من',
#   'أبرزها',
#   'أبرز',
#   'ها',
#   'المطالب',
#   'الكردية',
#   'التي',
#   'أكدت',
#   'ضرورة',
#   'أن',
#   'يتضمن',
#   'الدستور',
#   'العراقي',
#   'المقبل',
#   'نصاً',
#   'صريحاً',
#   'يقر',
#   'بالفيدرالية',
#   'ب',
#   'الفيدرالية',
#   'التي',
#   'تلبي',
#   'الحقوق',
#   'القومية',
#   'الكاملة',
#   'لأكراد',
#   'ل',
#   'أكراد',
#   'العراق',
#   '.'],
#  ['كما',
#   'استضافت',
#   'هانوي',
#   'مؤتمرا',
#   'اسيويا',
#   'للامم',
#   'ل',
#   'الأمم',
#   'المتحدة',
#   'حول',
#   'فلسطينيين',
#   'فى',
#   'اذار',
#   '/',
#   'مارس',
#   'الماضي',
#   '.'],
#  ['لم',
#   'يتأخر',
#   'رئيس',
#   '"',
#   'الموساد',
#   '"',
#   'في',
#   'القول',
#   'إن',
#   'التهديد',
#   'النووي',
#   'الإيراني',
#   'هو',
#   'أكبر',
#   'تهديد',
#   'لوجود',
#   'ل',
#   'وجود',
#   'إسرائيل',
#   'منذ',
#   'قيامها',
#   'قيام',
#   'ها',
#   'عام',
#   '1948',
#   '،',
#   'ولنا',
#   'و',
#   'ل',
#   'نا',
#   'أن',
#   'نتخيل',
#   'معنى',
#   'أن',
#   'نستيقظ',
#   'ذات',
#   'يوم',
#   'لنرى',
#   'ل',
#   'نرى',
#   'المنشآت',
#   'الإيرانية',
#   'ركاماً',
#   'على',
#   'غرار',
#   'ما',
#   'لحق',
#   'بالحلم',
#   'ب',
#   'الحلم',
#   'النووي',
#   'العراقي',
#   '.'],
#  ['وقال',
#   'و',
#   'قال',
#   'سعد',
#   'الدين',
#   'العثماني',
#   '،',
#   'نائب',
#   'الأمين',
#   'العام',
#   'لحزب',
#   'ل',
#   'حزب',
#   'العدالة',
#   'والتنمية',
#   'و',
#   'التنمية',
#   '"',
#   'لا',
#   'يمكن',
#   'إلا',
#   'أن',
#   'نرحّب',
#   'بهذه',
#   'ب',
#   'هٰذه',
#   'الترجمة',
#   'باعتبارها',
#   'ب',
#   'اعتبار',
#   'ها',
#   'عملاً',
#   'يستحق',
#   'التنويه',
#   'وضرورة',
#   'و',
#   'ضرورة',
#   'دينية',
#   'مادام',
#   'ما',
#   'دام',
#   'القرآن',
#   'قد',
#   'ترجم',
#   'إلى',
#   'مئات',
#   'من',
#   'اللغات',
#   'واللهجات',
#   'و',
#   'اللهجات',
#   '"',
#   '.'],
#  ['وكانت',
#   'و',
#   'كانت',
#   'قمة',
#   'كامب',
#   'ديفيد',
#   'الفلسطينية',
#   'الاسرائيلية',
#   'الاخيرة',
#   'فشلت',
#   'بسب',
#   'ب',
#   'سب',
#   'خلافات',
#   'الطرفين',
#   'الكبيرة',
#   'حول',
#   'قضايا',
#   'الوضع',
#   'النهائي',
#   'ولا',
#   'و',
#   'لا',
#   'سيما',
#   'القدس',
#   'واللاجئين',
#   'و',
#   'اللاجئين',
#   'والحدود',
#   'و',
#   'الحدود',
#   '.'],
#  ['ابوظبى', '3', 'مايو'],
#  ['واوضح',
#   'و',
#   'أوضح',
#   'الناطق',
#   'الرئاسي',
#   'السوري',
#   'جبران',
#   'كورية',
#   'ان',
#   'الرئيس',
#   'السوري',
#   'بشار',
#   'الاسد',
#   'كان',
#   'على',
#   'راس',
#   'مستقبليه',
#   'مستقبلي',
#   'ه',
#   'وعقد',
#   'و',
#   'عقد',
#   'معه',
#   'مع',
#   'ه',
#   'اجتماعا',
#   'موسعا',
#   'في',
#   'قصر',
#   'الشعب',
#   'حضره',
#   'حضر',
#   'ه',
#   'اعضاء',
#   'الوفدين',
#   'السوري',
#   'والقطري',
#   'و',
#   'القطري',
#   'ومن',
#   'و',
#   'من',
#   'بينهم',
#   'بين',
#   'هم',
#   'من',
#   'الجانب',
#   'السوري',
#   'نائبا',
#   'الرئيس',
#   'عبد',
#   'الحليم',
#   'خدام',
#   'وزهير',
#   'و',
#   'زهير',
#   'مشارقة',
#   'ورئيس',
#   'و',
#   'رئيس',
#   'الوزراء',
#   'محمد',
#   'مصطفى',
#   'ميرو',
#   'ووزير',
#   'و',
#   'وزير',
#   'الخارجية',
#   'فاروق',
#   'الشرع',
#   '.'],
#  ['فى',
#   'خلال',
#   '3',
#   'سنوات',
#   'من',
#   'تنفيذ',
#   'المشروع',
#   'جرت',
#   '14',
#   'دورا',
#   'تدريبية',
#   'استافد',
#   'منها',
#   'من',
#   'ها',
#   '500',
#   'مدير',
#   'مدرسة',
#   'ومدرس',
#   'و',
#   'مدرس',
#   '.'],
#  ['لأن',
#   'معظم',
#   'المصانع',
#   'التي',
#   'سيتم',
#   'س',
#   'يتم',
#   'إنشاؤها',
#   'إنشاء',
#   'ها',
#   'داخل',
#   'المناطق',
#   'الحرة',
#   '.'],
#  ['وأكد',
#   'و',
#   'أكد',
#   'أن',
#   'بلاده',
#   'بلاد',
#   'ه',
#   'لا',
#   'تستطيع',
#   'فرض',
#   'التغيير',
#   'في',
#   'مناهج',
#   'التعليم',
#   'بالمدارس',
#   'ب',
#   'المدارس',
#   'المصرية',
#   '.'],
#  ['تعتبر',
#   'الرسوم',
#   'الاعتباطية',
#   'أكبر',
#   'عائق',
#   'يقف',
#   'في',
#   'وجه',
#   'نمو',
#   'سياحة',
#   'اليخوت',
#   'في',
#   'مصر',
#   '،',
#   'ذلك',
#   'أنها',
#   'أن',
#   'ها',
#   'تقلل',
#   'من',
#   'فرص',
#   'زيادة',
#   'عدد',
#   'اليخوت',
#   'الوافدة',
#   'الى',
#   'البحر',
#   'الاحمر',
#   'وتؤدى',
#   'و',
#   'تؤدى',
#   'الى',
#   'إحجام',
#   'اصحاب',
#   'اليخوت',
#   'عن',
#   'زيارة',
#   'مصر',
#   'وتفضيلهم',
#   'و',
#   'تفضيل',
#   'هم',
#   'بدلاً',
#   'من',
#   'ذلك',
#   'التوجه',
#   'الى',
#   'الدول',
#   'المجاورة',
#   'التي',
#   'تسعى',
#   'الى',
#   'تقديم',
#   'مزيد',
#   'من',
#   'الحوافز',
#   'والتسهيلات',
#   'و',
#   'التسهيلات',
#   'وصولاً',
#   'الى',
#   'حد',
#   'إلغاء',
#   'الرسوم',
#   'نفسها',
#   'نفس',
#   'ها',
#   '.'],
#  ['وفي',
#   'و',
#   'في',
#   'إشارة',
#   'إلى',
#   'دور',
#   '"',
#   'الإخوان',
#   'المسلمين',
#   '"',
#   'في',
#   'العالم',
#   '،',
#   'قال',
#   'الهضيبي',
#   'إن',
#   'دور',
#   'المخلصين',
#   'المهمومين',
#   'بهموم',
#   'ب',
#   'هموم',
#   'الأمة',
#   'وشؤونها',
#   'و',
#   'شؤون',
#   'ها',
#   'اليوم',
#   'هو',
#   'السعي',
#   'لإرجاع',
#   'ل',
#   'إرجاع',
#   'الأمة',
#   'على',
#   'مستوى',
#   'الإنسان',
#   'والأسرة',
#   'و',
#   'الأسرة',
#   'والمجتمع',
#   'و',
#   'المجتمع',
#   'إلى',
#   'واحة',
#   'الإسلام',
#   'الوارفة',
#   '،',
#   'الأمر',
#   'الذي',
#   'يقتضي',
#   'أن',
#   'يكون',
#   'الداعية',
#   'أولا',
#   'إسلاما',
#   'يتحرك',
#   'على',
#   'وجه',
#   'الواقع',
#   'وقدوة',
#   'و',
#   'قدوة',
#   'أمام',
#   'أعين',
#   'الناس',
#   'تحسن',
#   'الإسلام',
#   'قولاً',
#   'وعملاً',
#   'و',
#   'عملا',
#   '"',
#   '.'],
#  ['وأكد',
#   'و',
#   'أكد',
#   'النواب',
#   '،',
#   'ومنهم',
#   'و',
#   'من',
#   'هم',
#   'الدكتور',
#   'طلعت',
#   'عبد',
#   'القوي',
#   'والدكتور',
#   'و',
#   'الدكتور',
#   'حسين',
#   'الصيرفي',
#   '،',
#   'وكيلا',
#   'لجنة',
#   'الصحة',
#   'الدكتور',
#   'أيمن',
#   'نور',
#   'وحيدر',
#   'و',
#   'حيدر',
#   'بغدادي',
#   'والدكتور',
#   'و',
#   'الدكتور',
#   'حمدي',
#   'حسن',
#   'والبدري',
#   'و',
#   'البدري',
#   'فرغلي',
#   'وأبو',
#   'و',
#   'أبو',
#   'العز',
#   'الحريري',
#   '،',
#   'في',
#   'طلبات',
#   'إحاطة',
#   'إلى',
#   'الدكتور',
#   'عاطف',
#   'عبيد',
#   'رئيس',
#   'الحكومة',
#   'والدكتور',
#   'و',
#   'الدكتور',
#   'محمد',
#   'عوض',
#   'تاج',
#   'الدين',
#   'وزير',
#   'الصحة',
#   'أن',
#   'هناك',
#   'ارتباطاً',
#   'كاملاً',
#   'بين',
#   'تزايد',
#   'أعداد',
#   'المرضى',
#   'النفسيين',
#   'والأوضاع',
#   'و',
#   'الأوضاع',
#   'الاقتصادية',
#   'الداخلية',
#   '.'],
#  ['واعلن',
#   'و',
#   'أعلن',
#   'الاميرال',
#   'كوروييدوف',
#   'خصوصا',
#   'انه',
#   'أن',
#   'ه',
#   'يخشى',
#   'من',
#   '"',
#   'نتائج',
#   'خطيرة',
#   '"',
#   'على',
#   'حياة',
#   'افراد',
#   'الطاقم',
#   '.'],
#  ['ويتنقل',
#   'و',
#   'يتنقل',
#   'المسؤولون',
#   'المصريون',
#   'منذ',
#   'اسابيع',
#   'بين',
#   'القاهرة',
#   'والاسكندرية',
#   'و',
#   'الإسكندرية',
#   '(',
#   'شمال',
#   ')',
#   'حيث',
#   'يوجد',
#   'المقر',
#   'الصيفي',
#   'للرئيس',
#   'ل',
#   'الرئيس',
#   'المصري',
#   'حسني',
#   'مبارك',
#   '.'],
#  ['فنجد',
#   'ف',
#   'نجد',
#   'أنه',
#   'أن',
#   'ه',
#   'على',
#   'الرغم',
#   'من',
#   'انخفاض',
#   'الدولار',
#   'أمام',
#   'العملات',
#   'الدولية',
#   'فلا',
#   'ف',
#   'لا',
#   'تأثير',
#   'لذلك',
#   'على',
#   'سوق',
#   'الدولار',
#   'الداخلي',
#   'لأنه',
#   'لأن',
#   'ه',
#   'سوق',
#   'منفصل',
#   'عن',
#   'السوق',
#   'العالمي',
#   '.'],
#  ['اعتبر',
#   'تقرير',
#   'أعدته',
#   'أعدت',
#   'ه',
#   'نخبة',
#   'من',
#   'مسؤولي',
#   'أجهزة',
#   'الاستخبارات',
#   'الإسرائيلية',
#   'السابقين',
#   'أن',
#   'غياب',
#   'الرئيس',
#   'ياسر',
#   'عرفات',
#   'سيفتح',
#   'س',
#   'يفتح',
#   'الباب',
#   'أمام',
#   'سيطرة',
#   '"',
#   'حركة',
#   'المقاومة',
#   'الإسلامية',
#   '"',
#   '(',
#   'حماس',
#   ')',
#   'على',
#   'زمام',
#   'السلطة',
#   'الفلسطينية',
#   'وسيجعل',
#   'و',
#   'س',
#   'يجعل',
#   'من',
#   'الصعوبة',
#   'بمكان',
#   'ب',
#   'مكان',
#   'إجراء',
#   'أي',
#   'مفاوضات',
#   'مع',
#   'الفلسطينيين',
#   '،',
#   'وإن',
#   'و',
#   'إن',
#   'حاولت',
#   'إسرائيل',
#   'ذلك',
#   'فإن',
#   'ف',
#   'إن',
#   'المفاوضات',
#   'ستكون',
#   'س',
#   'تكون',
#   '"',
#   'عقيمة',
#   'وغير',
#   'و',
#   'غير',
#   'ناجعة',
#   '"',
#   '.'],
#  ['وتبذل',
#   'و',
#   'تبذل',
#   'الحكومة',
#   'جهوداً',
#   'حثيثة',
#   'لجذب',
#   'ل',
#   'جذب',
#   'الاستثمارات',
#   'الأجنبية',
#   '،',
#   'لتعود',
#   'ل',
#   'تعود',
#   'وتتدفق',
#   'و',
#   'تتدفق',
#   'من',
#   'جديد',
#   'كما',
#   'حدث',
#   'في',
#   'الماضي',
#   'القريب',
#   '،',
#   'لأن',
#   'ذلك',
#   'قد',
#   'يكون',
#   'المصدر',
#   'الأقل',
#   'كلفة',
#   'من',
#   'نواح',
#   'عدة',
#   '.'],
#  ['اشتباكات', 'بالفلوجة', 'ب', 'الفلوجة', 'بعد', 'قصف', 'ليلي'],
#  ['في',
#   'نابل',
#   'اطلق',
#   'عيارا',
#   'ناريا',
#   '.',
#   'وتسبب',
#   'و',
#   'تسبب',
#   'لنفسه',
#   'ل',
#   'نفس',
#   'ه',
#   'في',
#   'كارثة'],
#  ['وقالت',
#   'و',
#   'قالت',
#   'مصادر',
#   'مصرية',
#   'وإيرانية',
#   'و',
#   'إيرانية',
#   'إن',
#   'إزالة',
#   'اسم',
#   'الإسلامبولي',
#   'يفتح',
#   'الطريق',
#   'أمام',
#   'زيارة',
#   'تاريخية',
#   'للرئيس',
#   'ل',
#   'الرئيس',
#   'المصري',
#   'حسني',
#   'مبارك',
#   'إلى',
#   'إيران',
#   '.'],
#  ['تعد',
#   '»',
#   'وكالة',
#   'الأمن',
#   'القومي',
#   '«',
#   '(',
#   'أن',
#   'أس',
#   'أيه',
#   ')',
#   'الوكالة',
#   'الأمنية',
#   'الاميركية',
#   'الوحيدة',
#   'التي',
#   'تعنى',
#   'في',
#   'شؤون',
#   'التشفير',
#   '،',
#   'وهي',
#   'و',
#   'هي',
#   'مهمة',
#   'بالغة',
#   'التخصص',
#   'وتهدف',
#   'و',
#   'تهدف',
#   'لحماية',
#   'ل',
#   'حماية',
#   'مصادر',
#   'المعلومات',
#   'في',
#   'الولايات',
#   'المتحدة',
#   '،',
#   'ونقل',
#   'و',
#   'نقل',
#   'المعلومات',
#   'من',
#   'خارج',
#   'اميركا',
#   'الى',
#   'المراكز',
#   'الأمنية',
#   'بأسلوب',
#   'ب',
#   'أسلوب',
#   'يكفل',
#   'بقاءها',
#   'بقاء',
#   'ها',
#   'سرية',
#   '.'],
#  ['أصيب',
#   'خمسة',
#   'طلاب',
#   'بجروح',
#   'ب',
#   'جروح',
#   'بالغة',
#   'بعد',
#   'تعرضهم',
#   'تعرض',
#   'هم',
#   'للضرب',
#   'ل',
#   'الضرب',
#   'بالهراوات',
#   'ب',
#   'الهراوات',
#   'والأحذية',
#   'و',
#   'الأحذية',
#   'الجلدية',
#   '.'],
#  ['ومن',
#   'و',
#   'من',
#   'المقرر',
#   'أن',
#   'يتناول',
#   'الحوار',
#   'قوانين',
#   'الأحزاب',
#   'والانتخابات',
#   'و',
#   'الانتخابات',
#   'والحقوق',
#   'و',
#   'الحقوق',
#   'السياسية',
#   '،',
#   'والسياسات',
#   'و',
#   'السياسات',
#   'الاقتصادية',
#   'وسبل',
#   'و',
#   'سبل',
#   'تطويرها',
#   'تطوير',
#   'ها',
#   'ودور',
#   'و',
#   'دور',
#   'الدولة',
#   'في',
#   'حماية',
#   'محدودي',
#   'الدخل',
#   'والفقراء',
#   'و',
#   'الفقراء',
#   '.'],
#  ['وسيتسلم',
#   'و',
#   'س',
#   'يتسلم',
#   'كل',
#   'مساهم',
#   'في',
#   'مجموعة',
#   'كريس',
#   '-',
#   'كرافت',
#   '34',
#   'دولارا',
#   'نقدا',
#   'و',
#   '1،1591',
#   'اسهم',
#   'تفضيلية',
#   'لنيوز',
#   'ل',
#   'نيوز',
#   'كورب',
#   '.',
#   'وقد',
#   'و',
#   'قد',
#   'اقفل',
#   'سهم',
#   'كريس',
#   '-',
#   'كرافت',
#   'على',
#   '62',
#   'دولارا',
#   'يوم',
#   'الجمعة',
#   '_',
#   'والسهم',
#   'و',
#   'السهم',
#   'التفضيلي',
#   'لنيوز',
#   'ل',
#   'نيوز',
#   'كورب',
#   'على',
#   '44',
#   'وواحد',
#   'و',
#   'واحد',
#   'على',
#   'ثمانية',
#   'دولارا',
#   '،',
#   'ما',
#   'يشكل',
#   'زيادة',
#   'بنسبة',
#   'ب',
#   'نسبة',
#   '37',
#   'في',
#   'المائة',
#   'للمساهمين',
#   'ل',
#   'المساهمين',
#   '.'],
#  ['والمكان',
#   'و',
#   'المكان',
#   'الذي',
#   'كانت',
#   'تقام',
#   'فيه',
#   'في',
#   'ه',
#   'أقيمت',
#   'عليه',
#   'علي',
#   'ه',
#   'عمارة',
#   'سكنية',
#   'ضخمة',
#   '.'],
#  ['وكان',
#   'و',
#   'كان',
#   'ثلاثة',
#   'عراقيين',
#   'قد',
#   'قتلوا',
#   'وأصيب',
#   'و',
#   'أصيب',
#   'عدد',
#   'آخر',
#   'بجروح',
#   'ب',
#   'جروح',
#   'مساء',
#   'اول',
#   'أمس',
#   'جراء',
#   'قصف',
#   'أمريكي',
#   'لحي',
#   'ل',
#   'حي',
#   'الجولان',
#   'والأطراف',
#   'و',
#   'الأطراف',
#   'الشمالية',
#   'للمدينة',
#   'ل',
#   'المدينة',
#   '.'],
#  ['وذكر',
#   'و',
#   'ذكر',
#   'وزير',
#   'خارجية',
#   'اليونان',
#   'ورئيس',
#   'و',
#   'رئيس',
#   'مجلس',
#   'وزراء',
#   'خارجية',
#   'الاتحاد',
#   'الاوربى',
#   'جورج',
#   'باباندريو',
#   'ان',
#   'الوزراء',
#   'اصدروا',
#   'تعليماتهم',
#   'تعليمات',
#   'هم',
#   'للمفوض',
#   'ل',
#   'المفوض',
#   'الاعلى',
#   'للاتحاد',
#   'ل',
#   'الاتحاد',
#   'الاوروبى',
#   'خافيير',
#   'سولانا',
#   'لاعداد',
#   'ل',
#   'إعداد',
#   'الاقتراحات',
#   'ذات',
#   'الصلة',
#   'لرفعها',
#   'ل',
#   'رفع',
#   'ها',
#   'لمجلس',
#   'ل',
#   'مجلس',
#   'الشئون',
#   'العامة',
#   'فى',
#   'يونيو',
#   'بهدف',
#   'ب',
#   'هدف',
#   'مناقشتها',
#   'مناقشة',
#   'ها',
#   'فى',
#   'النهاية',
#   'فى',
#   'قمة',
#   'سالونيك',
#   'للاتحاد',
#   'ل',
#   'الاتحاد',
#   'الاوروبى',
#   '.'],
#  ['وسوف',
#   'و',
#   'سوف',
#   'تعمل',
#   'جميع',
#   'المشروعات',
#   'الجديدة',
#   'تقريبا',
#   'فى',
#   'المقاطعات',
#   'والمدن',
#   'و',
#   'المدن',
#   'الواقعة',
#   'جنوبى',
#   'البلاد',
#   '،',
#   'فى',
#   'حين',
#   'أن',
#   'نصيب',
#   'المقاطعات',
#   'والمدن',
#   'و',
#   'المدن',
#   'الشمالية',
#   'هو',
#   '52',
#   'مشروعا',
#   'فقط',
#   'برأسمال',
#   'ب',
#   'رأسمال',
#   'استثمارى',
#   'مجمع',
#   'يبلغ',
#   '120',
#   'مليون',
#   'دولار',
#   '.'],
#  ['قال',
#   'مسئول',
#   'في',
#   'الشركة',
#   'بصراحة',
#   'ب',
#   'صراحة',
#   'نعرف',
#   'جميعاً',
#   'أن',
#   'السيدات',
#   'يحتكرن',
#   'مناصب',
#   'بعينها',
#   'ب',
#   'عين',
#   'ها',
#   'في',
#   'القطاع',
#   'الخاص',
#   'ـ',
#   'السكرتيرات',
#   'التنفيذيات',
#   'مثلا',
#   'ـ',
#   'وهن',
#   'و',
#   'هن',
#   'منتشرات',
#   'في',
#   'المهن',
#   'الخاصة',
#   'المتميزة',
#   '.'],
#  ['إلا',
#   'أن',
#   'المصدر',
#   'رفض',
#   'الإدلاء',
#   'بموعد',
#   'ب',
#   'موعد',
#   'الانتهاء',
#   'من',
#   'الصفقة',
#   'وإعلانها',
#   'و',
#   'إعلان',
#   'ها',
#   'أو',
#   'السعر',
#   'النهائي',
#   'الذي',
#   'تم',
#   'التوصل',
#   'إليه',
#   'إلي',
#   'ه',
#   'بين',
#   'الطرفين',
#   'واكتفى',
#   'و',
#   'اكتفى',
#   'بالقول',
#   'ب',
#   'القول',
#   'إن',
#   'هناك',
#   'مشاورات',
#   'تتم',
#   'بين',
#   'الجهاز',
#   'المركزي',
#   'للمحاسبات',
#   'ل',
#   'المحاسبات',
#   'وبنك',
#   'و',
#   'بنك',
#   'القاهرة',
#   '.'],
#  ['فازددنا', 'ف', 'ازددنا', 'إيماناً', 'بفكره', 'ب', 'فكر', 'ه', '.', '.'],
#  ['ويتعاون',
#   'و',
#   'يتعاون',
#   'المجلس',
#   'القومي',
#   'للطفولة',
#   'ل',
#   'الطفولة',
#   'والأمومة',
#   'و',
#   'الأمومة',
#   'راهناً',
#   'مع',
#   'صندوق',
#   'الأمم',
#   'المتحدة',
#   'للسكان',
#   'ل',
#   'السكان',
#   '،',
#   'لتنمية',
#   'ل',
#   'تنمية',
#   'القدرات',
#   'الفردية',
#   'للمراهقات',
#   'ل',
#   'المراهقات',
#   '،',
#   'وتمكينهن',
#   'و',
#   'تمكين',
#   'هن',
#   'من',
#   'ممارسة',
#   'حقوقهن',
#   'حقوق',
#   'هن',
#   'في',
#   'التعبير',
#   'عن',
#   'آرائهن',
#   'آراء',
#   'هن',
#   'طبقا',
#   'لوجهة',
#   'ل',
#   'وجهة',
#   'نظرهن',
#   'نظر',
#   'هن',
#   '،',
#   'من',
#   'أجل',
#   'تحديد',
#   'حاجاتهن',
#   'حاجات',
#   'هن',
#   'في',
#   'مجال',
#   'الصحة',
#   'الإنجابية',
#   '،',
#   'وتوفير',
#   'و',
#   'توفير',
#   'الخدمات',
#   'والمعلومات',
#   'و',
#   'المعلومات',
#   'الخاصة',
#   'في',
#   'هذا',
#   'المجال',
#   'للمراهقين',
#   'ل',
#   'المراهقين',
#   'على',
#   'مستوى',
#   'المدارس',
#   '.'],
#  ['لكن',
#   'المشكلة',
#   'المهمة',
#   'الاخرى',
#   'التي',
#   'واجهت',
#   'التلاميذ',
#   'كانت',
#   'مشكلة',
#   'المواصلات',
#   'التي',
#   'تعيق',
#   'وصولهم',
#   'وصول',
#   'هم',
#   'الى',
#   'مدارسهم',
#   'مدارس',
#   'هم',
#   '.',
#   'ففي',
#   'ف',
#   'في',
#   'غياب',
#   'حافلات',
#   'النقل',
#   'العام',
#   'وشحة',
#   'وقود',
#   'السيارات',
#   'اصبح',
#   'من',
#   'العسير',
#   'على',
#   'التلاميذ',
#   'الوصول',
#   'الى',
#   'مدارسهم',
#   'مدارس',
#   'هم',
#   'ما',
#   'لم',
#   'تكن',
#   'تلك',
#   'المدارس',
#   'قريبة',
#   'من',
#   'مقار',
#   'سكناهم',
#   'سكنى',
#   'هم',
#   '.'],
#  ...]

# %% [markdown]
# ### Cleaning and Preprocessing

# %% [markdown]
# Tokenization:
# i don't find a need for tokenization because the sentences are already splitted into tokens in the upper loop

# %%
# Convert words to indices
word_to_index = {word: i + 1 for i, word in enumerate(set(word for sentence in sentences_train + sentences_test for word in sentence))}
index_to_word = {i: word for word, i in word_to_index.items()}

indexed_sentences_train = [[word_to_index[word] for word in sentence] for sentence in sentences_train]
indexed_sentences_test = [[word_to_index[word] for word in sentence] for sentence in sentences_test]

# %%
# Padding sequences
max_len_train = max(len(sentence) for sentence in indexed_sentences_train)
max_len_test = max(len(sentence) for sentence in indexed_sentences_test)

padded_sentences_train = pad_sequences(indexed_sentences_train, maxlen=max_len_train, padding='post')
padded_sentences_test = pad_sequences(indexed_sentences_test, maxlen=max_len_test, padding='post')

# %%
# Convert UPOS tags to indices
upos_to_index = {upos: i for i, upos in enumerate(set(tag for tags in upos_tags_train for tag in tags))}
index_to_upos = {i: upos for upos, i in upos_to_index.items()}

indexed_tags_train = [[upos_to_index[tag] for tag in tags] for tags in upos_tags_train]
indexed_tags_test = [[upos_to_index[tag] for tag in tags] for tags in upos_tags_test]

# %%
# Padding sequences
padded_tags_train = pad_sequences(indexed_tags_train, maxlen=max_len_train, padding='post')
padded_tags_test = pad_sequences(indexed_tags_test, maxlen=max_len_test, padding='post')

# %%
# encoding tags
one_hot_tags_train = to_categorical(padded_tags_train, num_classes=len(upos_to_index))
one_hot_tags_test = to_categorical(padded_tags_test, num_classes=len(upos_to_index))

# %% [markdown]
# ### Modelling

# %% [markdown]
# #### LSTM

# %%
model = Sequential()
model.add(Embedding(input_dim=len(word_to_index) + 1, output_dim=100, input_length=max_len_train))
model.add(LSTM(units=128, return_sequences=True))
model.add(Dense(len(upos_to_index), activation='softmax'))
# Out:
# D:\iti\python\conda\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(padded_sentences_train, one_hot_tags_train, validation_split=0.2, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 65s 504ms/step - accuracy: 0.8893 - loss: 0.4832 - val_accuracy: 0.9530 - val_loss: 0.1673
# Epoch 2/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 514ms/step - accuracy: 0.9595 - loss: 0.1392 - val_accuracy: 0.9746 - val_loss: 0.0914
# Epoch 3/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 61s 496ms/step - accuracy: 0.9782 - loss: 0.0791 - val_accuracy: 0.9853 - val_loss: 0.0556
# Epoch 4/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 62s 506ms/step - accuracy: 0.9895 - loss: 0.0454 - val_accuracy: 0.9913 - val_loss: 0.0367
# Epoch 5/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 61s 499ms/step - accuracy: 0.9954 - loss: 0.0260 - val_accuracy: 0.9927 - val_loss: 0.0280
# Epoch 6/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 61s 503ms/step - accuracy: 0.9974 - loss: 0.0158 - val_accuracy: 0.9934 - val_loss: 0.0243
# Epoch 7/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 522ms/step - accuracy: 0.9980 - loss: 0.0113 - val_accuracy: 0.9934 - val_loss: 0.0228
# Epoch 8/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 518ms/step - accuracy: 0.9984 - loss: 0.0082 - val_accuracy: 0.9933 - val_loss: 0.0220
# Epoch 9/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 514ms/step - accuracy: 0.9986 - loss: 0.0065 - val_accuracy: 0.9933 - val_loss: 0.0222
# Epoch 10/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 521ms/step - accuracy: 0.9988 - loss: 0.0054 - val_accuracy: 0.9932 - val_loss: 0.0224

# %% [markdown]
# #### Evaluation

# %% [markdown]
# **Evaluation metric:**
# Accuracy

# %%
loss, accuracy = model.evaluate(padded_sentences_test, one_hot_tags_test)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.9863 - loss: 0.0452

# %%
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 98.55%

# %% [markdown]
# ### Enhancement

# %% [markdown]
# ### GRU

# %%
gru = Sequential()
gru.add(Embedding(input_dim=len(word_to_index) + 1, output_dim=100, input_length=max_len_train))
gru.add(GRU(units=128, return_sequences=True))
gru.add(Dense(len(upos_to_index), activation='softmax'))

# %%
 gru.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
gru.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
history = gru.fit(padded_sentences_train, one_hot_tags_train, validation_split=0.2, epochs=10, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 66s 508ms/step - accuracy: 0.8975 - loss: 0.4834 - val_accuracy: 0.9676 - val_loss: 0.1072
# Epoch 2/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 522ms/step - accuracy: 0.9746 - loss: 0.0885 - val_accuracy: 0.9860 - val_loss: 0.0533
# Epoch 3/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 521ms/step - accuracy: 0.9901 - loss: 0.0421 - val_accuracy: 0.9917 - val_loss: 0.0320
# Epoch 4/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 521ms/step - accuracy: 0.9960 - loss: 0.0211 - val_accuracy: 0.9933 - val_loss: 0.0242
# Epoch 5/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 63s 519ms/step - accuracy: 0.9977 - loss: 0.0121 - val_accuracy: 0.9935 - val_loss: 0.0218
# Epoch 6/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 526ms/step - accuracy: 0.9982 - loss: 0.0080 - val_accuracy: 0.9935 - val_loss: 0.0212
# Epoch 7/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 66s 537ms/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9934 - val_loss: 0.0213
# Epoch 8/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 525ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9930 - val_loss: 0.0224
# Epoch 9/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 64s 527ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9932 - val_loss: 0.0223

# %%
loss, accuracy = gru.evaluate(padded_sentences_test, one_hot_tags_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9866 - loss: 0.0429
# Test Accuracy: 98.58%

# %% [markdown]
# ### Conclusion and final results

# %% [markdown]
# - gru model is slightly better than lstm this may be due to sentence lengths or  language nuances

# %% [markdown]
# #### Done!
